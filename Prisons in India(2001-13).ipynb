# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading CSV File.

# %%
df = pd.read_csv('G:/DOCUMENTS/Prison in India(2001-13).csv')
df.head(10)
# Out:
#       State_Name  is_state  Year    Category          Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners      Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners      Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners       Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners       Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners        Others  Female        0.0
# 5  A & N Islands         0  2001  Foreigners        Others    Male        0.0
# 6  A & N Islands         0  2001  Foreigners  Under Trials  Female        0.0
# 7  A & N Islands         0  2001  Foreigners  Under Trials    Male        0.0
# 8  A & N Islands         0  2001     Indians      Convicts  Female        0.0
# 9  A & N Islands         0  2001     Indians      Convicts    Male        0.0
#
#    Age 18-30  Age 30-50  Age 50+
# 0          0          0        0
# 1         12        139        2
# ...

# %%
# For analysing various information about the dataset and it's columns.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7152 entries, 0 to 7151
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   State_Name  7152 non-null   object
#  1   is_state    7152 non-null   int64
#  2   Year        7152 non-null   int64
#  3   Category    7152 non-null   object
#  4   Type        7152 non-null   object
#  5   Gender      7152 non-null   object
#  6   Age 16-18   7151 non-null   float64
#  7   Age 18-30   7152 non-null   int64
#  8   Age 30-50   7152 non-null   int64
#  9   Age 50+     7152 non-null   int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 558.9+ KB

# %%
df.shape
# That means NO NaNs.
# Out:
# (7152, 10)

# %% [markdown]
# ### Making new Column.

# %%
df['Total(Age)']= df.iloc[:, 6:].sum(axis=1)

# %%
df.head(10)
# Out:
#       State_Name  is_state  Year    Category          Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners      Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners      Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners       Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners       Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners        Others  Female        0.0
# 5  A & N Islands         0  2001  Foreigners        Others    Male        0.0
# 6  A & N Islands         0  2001  Foreigners  Under Trials  Female        0.0
# 7  A & N Islands         0  2001  Foreigners  Under Trials    Male        0.0
# 8  A & N Islands         0  2001     Indians      Convicts  Female        0.0
# 9  A & N Islands         0  2001     Indians      Convicts    Male        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# ...

# %% [markdown]
# ### Grouping by State_Name.

# %%
df.groupby('State_Name').sum().drop(['is_state', 'Year'], axis='columns')
# Out:
#                    Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# State_Name
# A & N Islands            0.0       2480       3634      631      6745.0
# Andhra Pradesh         252.0      74755      89287    15452    179746.0
# Arunachal Pradesh        1.0        243         82       11       337.0
# Assam                  444.0      42694      49895    11301    104334.0
# Bihar                 1260.0     171128     215927    73986    462301.0
# Chandigarh              21.0       2609       3329     1221      7180.0
# Chhattisgarh           941.0      68611      64476    14835    148863.0
# D & N Haveli             0.0        604        240       18       862.0
# Daman & Diu              2.0        269        205       36       512.0
# Delhi                  486.0      97914      49557     8655    156612.0
# Goa                     14.0       2955       2421      278      5668.0
# Gujarat                391.0      67843      64692    13884    146810.0
# ...

# %%
results = df.groupby('State_Name').sum()
states = [State_Name for State_Name, df1 in df.groupby('State_Name')]

plt.figure(figsize=(10,5))

plt.bar(states, results['Total(Age)'])

plt.xticks(states, rotation = 'vertical', size=12)

plt.ylabel('Number', size=13)

plt.show()

# %% [markdown]
# ### Grouping by Years.

# %%
df.groupby('Year').sum().drop('is_state', axis='columns')
# Out:
#       Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Year
# 2001     5752.0     139747     136789    31347    313635.0
# 2002     3877.0     147206     137181    34093    322357.0
# 2003     2152.0     141362     146791    36214    326519.0
# 2004     1055.0     141115     151803    37418    331391.0
# 2005     1370.0     154557     159720    42721    358368.0
# 2006      663.0     154864     171517    46227    373271.0
# 2007      495.0     162729     170874    42298    376396.0
# 2008      174.0     160080     177359    47140    384753.0
# 2009       64.0     163198     166278    47429    376969.0
# 2010      257.0     160044     162044    46653    368998.0
# 2011       95.0     164147     161226    47458    372926.0
# 2012      106.0     162694     169471    52864    385135.0
# 2013       33.0     173874     184286    53799    411992.0

# %%
result1 = df.groupby('Year').sum().drop('is_state', axis='columns')
year = np.arange(2001,2014)

plt.figure(figsize=(8,4))

plt.plot(year, result1['Total(Age)'])

plt.xticks(year, rotation = 'vertical')

plt.xlabel("Year", size=13)
plt.ylabel("Number", size=13)

plt.show()

# %% [markdown]
# ## Male vs Female.

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %%
grpGender = df.groupby('Gender').sum()
grpGender
# Out:
#         is_state     Year  Age 16-18  Age 18-30  Age 30-50  Age 50+  \
# Gender
# Female      2848  7177192      293.0      65172      96113    28892
# Male        2848  7177192    15800.0    1960445    1999226   536769
#
#         Total(Age)
# Gender
# Female    190470.0
# Male     4512240.0

# %%
gender = ['Female', 'Male']

plt.bar(gender, grpGender['Total(Age)'])

plt.ylabel("Number", size=13)

plt.show()

# %% [markdown]
# ## Comparison of Gender of Prisoners in different States.

# %%
grpGenderState = df.groupby(['State_Name','Gender']).sum().drop(['is_state','Year'], axis='columns')
grpGenderState
# Out:
#                           Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# State_Name        Gender
# A & N Islands     Female        0.0         21         29        2        52.0
#                   Male          0.0       2459       3605      629      6693.0
# Andhra Pradesh    Female        4.0       3194       5783     1500     10481.0
#                   Male        248.0      71561      83504    13952    169265.0
# Arunachal Pradesh Female        0.0          9         10        0        19.0
# ...                             ...        ...        ...      ...         ...
# Uttar Pradesh     Male       3540.0     340127     389720   139253    872640.0
# Uttaranchal       Female        0.0        502        567      241      1310.0
#                   Male        343.0      15522      14403     6495     36763.0
# West Bengal       Female      101.0       5799       6223     2177     14300.0
#                   Male        868.0      99016      98540    24975    223399.0
# ...

# %%
Total = grpGenderState['Total(Age)']
Total
# Out:
# State_Name         Gender
# A & N Islands      Female        52.0
#                    Male        6693.0
# Andhra Pradesh     Female     10481.0
#                    Male      169265.0
# Arunachal Pradesh  Female        19.0
#                                ...
# Uttar Pradesh      Male      872640.0
# Uttaranchal        Female      1310.0
#                    Male       36763.0
# West Bengal        Female     14300.0
#                    Male      223399.0
# Name: Total(Age), Length: 70, dtype: float64

# %%
female = Total.take(np.arange(0,70,2))
female.head()
# Out:
# State_Name         Gender
# A & N Islands      Female       52.0
# Andhra Pradesh     Female    10481.0
# Arunachal Pradesh  Female       19.0
# Assam              Female     3291.0
# Bihar              Female    13928.0
# Name: Total(Age), dtype: float64

# %%
male = Total.take(np.arange(1,70,2))
male.head()
# Out:
# State_Name         Gender
# A & N Islands      Male        6693.0
# Andhra Pradesh     Male      169265.0
# Arunachal Pradesh  Male         318.0
# Assam              Male      101043.0
# Bihar              Male      448373.0
# Name: Total(Age), dtype: float64

# %%
state_name = [st for st, df2 in df.groupby('State_Name')]
state_name
# Out:
# ['A & N Islands',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'D & N Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Orissa',
#  'Pondicherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttaranchal',
#  'West Bengal']

# %%
N = 35
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(15,5))

plt.bar(ind, female, width, label='Female')
plt.bar(ind+width, male, width, label='Male')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, state_name, rotation = 'vertical')
plt.legend()

plt.show()

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %% [markdown]
# ## Category.

# %%
df.Category.unique()
# Out:
# array(['Foreigners', 'Indians'], dtype=object)

# %%
grpCategoryGender = df.groupby(['Category','Gender']).sum().drop(['is_state','Year'], axis='columns')
grpCategoryGender
# Out:
#                    Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Category   Gender
# Foreigners Female       59.0       3466       3019      496      7040.0
#            Male        268.0      23495      23093     4057     50913.0
# Indians    Female      234.0      61706      93094    28396    183430.0
#            Male      15532.0    1936950    1976133   532712   4461327.0

# %%
f = grpCategoryGender['Total(Age)']
f = f.take([0,2])
f
# Out:
# Category    Gender
# Foreigners  Female      7040.0
# Indians     Female    183430.0
# Name: Total(Age), dtype: float64

# %%
m = grpCategoryGender['Total(Age)']
m = m.take([1,3])
m
# Out:
# Category    Gender
# Foreigners  Male        50913.0
# Indians     Male      4461327.0
# Name: Total(Age), dtype: float64

# %%
fm = [f[0],m[0]]
fm
# Out:
# [7040.0, 50913.0]

# %%
plt.bar(['Female','Male'],fm)

plt.xlabel('Foreigners', size=13)
plt.ylabel('Number', size=13)

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners on grounds of sex and category(foreigner or indian).

# %%
N = 2
ind = np.arange(N)
width = 0.3

plt.bar(ind, f, width, label='Female')
plt.bar(ind+width, m, width, label='Male')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Foreigners', 'Indians'], rotation = 'vertical')
plt.legend()

plt.show()

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %% [markdown]
# ## How many prisoners are Convicts, Detenus, Under Trials and Others?

# %%
df.Type.unique()
# Out:
# array(['Convicts', 'Detenus', 'Others', 'Under Trials'], dtype=object)

# %%
grpType = df.groupby('Type').sum().drop(['is_state','Year'], axis='columns')
grpType
# Out:
#               Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Type
# Convicts         1419.0     526455     702507   222084   1452465.0
# Detenus           366.0      17822      19620     3338     41146.0
# Others            254.0      25069      43702     5594     74619.0
# Under Trials    14054.0    1456271    1329510   334645   3134480.0

# %%
Type = ['Convicts', 'Detenus', 'Others', 'Under Trials']

plt.bar(Type, grpType['Total(Age)'])

plt.ylabel('Number', size=13)

plt.show()

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %% [markdown]
# ## How many Prisoners of age 16-18 are present in different states of India?

# %%
results = df.groupby('State_Name').sum()
states = [State_Name for State_Name, df1 in df.groupby('State_Name')]

plt.figure(figsize=(10,5))

plt.bar(states, results['Age 16-18'])

plt.xticks(states, rotation = 'vertical', size=12)

plt.ylabel('Number', size=13)

plt.show()

# %% [markdown]
# ## How many Prisoners of age 18-30 are present in different states of India?

# %%
results = df.groupby('State_Name').sum()
states = [State_Name for State_Name, df1 in df.groupby('State_Name')]

plt.figure(figsize=(10,5))

plt.bar(states, results['Age 18-30'])

plt.xticks(states, rotation = 'vertical', size=12)

plt.ylabel('Number', size=13)

plt.show()

# %% [markdown]
# ## How many Prisoners of age 30-50 are present in different states of India?

# %%
results = df.groupby('State_Name').sum()
states = [State_Name for State_Name, df1 in df.groupby('State_Name')]

plt.figure(figsize=(10,5))

plt.bar(states, results['Age 30-50'])

plt.xticks(states, rotation = 'vertical', size=12)

plt.ylabel('Number', size=13)

plt.show()

# %% [markdown]
# ## How many Prisoners of age 50+ are present in different states of India?

# %%
results = df.groupby('State_Name').sum()
states = [State_Name for State_Name, df1 in df.groupby('State_Name')]

plt.figure(figsize=(10,5))

plt.bar(states, results['Age 50+'])

plt.xticks(states, rotation = 'vertical', size=12)

plt.ylabel('Number', size=13)

plt.show()

# %% [markdown]
# ## Which age group has most number of Prisoners?

# %%
# Adding columns Age 16-18, Age 18-30, Age 30-50 and Age 50+ seperately and saving in a list.

n = [grpType['Age 16-18'].sum(), grpType['Age 18-30'].sum(), grpType['Age 30-50'].sum(), grpType['Age 50+'].sum()]
n
# Out:
# [16093.0, 2025617, 2095339, 565661]

# %%
Age = ['Age 16-18', 'Age 18-30', 'Age 30-50', 'Age 50+']

plt.bar(Age, n)

plt.ylabel('Number', size=13)

plt.show()

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %% [markdown]
# ## Comparison of No. of Prisoners on grounds of sex and Type(Convicts, Detenus etc.).

# %%
grpTypeGender = df.groupby(['Type','Gender']).sum().drop(['is_state','Year'], axis='columns')
grpTypeGender
# Out:
#                      Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Type         Gender
# Convicts     Female       11.0      14266      27245    10492     52014.0
#              Male       1408.0     512189     675262   211592   1400451.0
# Detenus      Female        3.0        492       1200      227      1922.0
#              Male        363.0      17330      18420     3111     39224.0
# Others       Female       15.0       1843       5854     1010      8722.0
#              Male        239.0      23226      37848     4584     65897.0
# Under Trials Female      264.0      48571      61814    17163    127812.0
#              Male      13790.0    1407700    1267696   317482   3006668.0

# %%
TypeGenTotal = grpTypeGender['Total(Age)']
TypeGenTotalF = TypeGenTotal.take(np.arange(0,7,2))
TypeGenTotalF
# Out:
# Type          Gender
# Convicts      Female     52014.0
# Detenus       Female      1922.0
# Others        Female      8722.0
# Under Trials  Female    127812.0
# Name: Total(Age), dtype: float64

# %%
TypeGenTotalM = TypeGenTotal.take(np.arange(1,8,2))
TypeGenTotalM
# Out:
# Type          Gender
# Convicts      Male      1400451.0
# Detenus       Male        39224.0
# Others        Male        65897.0
# Under Trials  Male      3006668.0
# Name: Total(Age), dtype: float64

# %%
N = 4
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, TypeGenTotalF, width, label='Female')
plt.bar(ind+width, TypeGenTotalM, width, label='Male')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, Type, rotation = 'vertical')
plt.legend()

plt.show()

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %% [markdown]
# ## How many prisoners of age 16-18 are Convicts, Detenus, Under Trials and Others?

# %%
plt.bar(Type, grpType['Age 16-18'])

plt.ylabel("Number", size=13)

plt.show()

# %% [markdown]
# ## How many prisoners of age 18-30 are Convicts, Detenus, Under Trials and Others?

# %%
plt.bar(Type, grpType['Age 18-30'])

plt.ylabel("Number", size=13)

plt.show()

# %% [markdown]
# ## How many prisoners of age 30-50 are Convicts, Detenus, Under Trials and Others?

# %%
plt.bar(Type, grpType['Age 30-50'])

plt.ylabel("Number", size=13)

plt.show()

# %% [markdown]
# ## How many prisoners of age 50+ are Convicts, Detenus, Under Trials and Others?

# %%
plt.bar(Type, grpType['Age 50+'])

plt.ylabel("Number", size=13)

plt.show()

# %% [markdown]
# ## Comparison of No. of foreign Prisoners of different age groups.

# %%
listgrpCategoryGenderFor = [grpCategoryGender['Age 16-18'][0]+grpCategoryGender['Age 16-18'][1],
                            grpCategoryGender['Age 18-30'][0]+grpCategoryGender['Age 18-30'][1],
                            grpCategoryGender['Age 30-50'][0]+grpCategoryGender['Age 30-50'][1],
                            grpCategoryGender['Age 50+'][0]+grpCategoryGender['Age 50+'][1]]
listgrpCategoryGenderFor
# Out:
# [327.0, 26961, 26112, 4553]

# %%
plt.bar(Age, listgrpCategoryGenderFor)

plt.ylabel("Number", size=13)

plt.show()

# %% [markdown]
# ## Comparison of No. of Indian Prisoners of different age groups.

# %%
listgrpCategoryGenderIN = [grpCategoryGender['Age 16-18'][2]+grpCategoryGender['Age 16-18'][3],
                           grpCategoryGender['Age 18-30'][2]+grpCategoryGender['Age 18-30'][3],
                           grpCategoryGender['Age 30-50'][2]+grpCategoryGender['Age 30-50'][3],
                           grpCategoryGender['Age 50+'][2]+grpCategoryGender['Age 50+'][3]]
listgrpCategoryGenderIN
# Out:
# [15766.0, 1998656, 2069227, 561108]

# %%
plt.bar(Age, listgrpCategoryGenderIN)

plt.ylabel("Number", size=13)

plt.show()

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %% [markdown]
# ## Comparison of No. of Prisoners in different age groups and different gender/sex.

# %%
grpCategoryGender
# Out:
#                    Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Category   Gender
# Foreigners Female       59.0       3466       3019      496      7040.0
#            Male        268.0      23495      23093     4057     50913.0
# Indians    Female      234.0      61706      93094    28396    183430.0
#            Male      15532.0    1936950    1976133   532712   4461327.0

# %%
AgeF = [grpCategoryGender['Age 16-18'][0]+grpCategoryGender['Age 16-18'][2], 
        grpCategoryGender['Age 18-30'][0]+grpCategoryGender['Age 18-30'][2],
        grpCategoryGender['Age 30-50'][0]+grpCategoryGender['Age 30-50'][2],
        grpCategoryGender['Age 50+'][0]+grpCategoryGender['Age 50+'][2]]
print(AgeF)
# Out:
# [293.0, 65172, 96113, 28892]

# %%
AgeM = [grpCategoryGender['Age 16-18'][1]+grpCategoryGender['Age 16-18'][3], 
        grpCategoryGender['Age 18-30'][1]+grpCategoryGender['Age 18-30'][3],
        grpCategoryGender['Age 30-50'][1]+grpCategoryGender['Age 30-50'][3],
        grpCategoryGender['Age 50+'][1]+grpCategoryGender['Age 50+'][3]]
print(AgeM)
# Out:
# [15800.0, 1960445, 1999226, 536769]

# %%
N = 4
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, AgeF, width, label='Female')
plt.bar(ind+width, AgeM, width, label='Male')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, Age, rotation = 'vertical')
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners on grounds of Gender over different years.

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %%
grpYearGen = df.groupby(['Year', 'Gender']).sum().drop('is_state', axis='columns')
grpYearGen
# Out:
#              Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Year Gender
# 2001 Female       62.0       3959       5566     1507     11094.0
#      Male       5690.0     135788     131223    29840    302541.0
# 2002 Female       82.0       4393       6131     1441     12047.0
#      Male       3795.0     142813     131050    32652    310310.0
# 2003 Female       16.0       4226       7026     1512     12780.0
#      Male       2136.0     137136     139765    34702    313739.0
# 2004 Female       26.0       4190       7005     1749     12970.0
#      Male       1029.0     136925     144798    35669    318421.0
# 2005 Female       12.0       4964       6954     2056     13986.0
#      Male       1358.0     149593     152766    40665    344382.0
# 2006 Female       14.0       4807       7575     2261     14657.0
#      Male        649.0     150057     163942    43966    358614.0
# 2007 Female       47.0       5731       7461     2162     15401.0
# ...

# %%
totalAgeYearGen = grpYearGen['Total(Age)']
totalAgeYearGen
# Out:
# Year  Gender
# 2001  Female     11094.0
#       Male      302541.0
# 2002  Female     12047.0
#       Male      310310.0
# 2003  Female     12780.0
#       Male      313739.0
# 2004  Female     12970.0
#       Male      318421.0
# 2005  Female     13986.0
#       Male      344382.0
# 2006  Female     14657.0
#       Male      358614.0
# 2007  Female     15401.0
#       Male      360995.0
# 2008  Female     15929.0
#       Male      368824.0
# 2009  Female     15406.0
#       Male      361563.0
# 2010  Female     15037.0
#       Male      353961.0
# 2011  Female     16024.0
#       Male      356902.0
# 2012  Female     16951.0
#       Male      368184.0
# 2013  Female     18188.0
#       Male      393804.0
# Name: Total(Age), dtype: float64

# %%
listgrpYearGenF = totalAgeYearGen.take(np.arange(0,26,2))
listgrpYearGenF
# Out:
# Year  Gender
# 2001  Female    11094.0
# 2002  Female    12047.0
# 2003  Female    12780.0
# 2004  Female    12970.0
# 2005  Female    13986.0
# 2006  Female    14657.0
# 2007  Female    15401.0
# 2008  Female    15929.0
# 2009  Female    15406.0
# 2010  Female    15037.0
# 2011  Female    16024.0
# 2012  Female    16951.0
# 2013  Female    18188.0
# Name: Total(Age), dtype: float64

# %%
listgrpYearGenM = totalAgeYearGen.take(np.arange(1,26,2))
listgrpYearGenM
# Out:
# Year  Gender
# 2001  Male      302541.0
# 2002  Male      310310.0
# 2003  Male      313739.0
# 2004  Male      318421.0
# 2005  Male      344382.0
# 2006  Male      358614.0
# 2007  Male      360995.0
# 2008  Male      368824.0
# 2009  Male      361563.0
# 2010  Male      353961.0
# 2011  Male      356902.0
# 2012  Male      368184.0
# 2013  Male      393804.0
# Name: Total(Age), dtype: float64

# %%
N = 13
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, listgrpYearGenF, width, label='Female')
plt.bar(ind+width, listgrpYearGenM, width, label='Male')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, np.arange(2001,2014), rotation = 'vertical')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), listgrpYearGenF, label='Female')
plt.plot(np.arange(2001,2014), listgrpYearGenM, label='Male')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners on grounds of Type(Convicts, Detenus etc) over different years.

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %%
grpYearType = df.groupby(['Year', 'Type']).sum().drop('is_state', axis='columns')
grpYearType
# Out:
#                    Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Year Type
# 2001 Convicts          449.0      30258      35196     9760     75663.0
#      Detenus            14.0       1594       1554      126      3288.0
#      Others             75.0       5859       6953      980     13867.0
#      Under Trials     5214.0     102036      93086    20481    220817.0
# 2002 Convicts          401.0      33603      38475     9642     82121.0
#      Detenus            52.0       2177       2209      394      4832.0
#      Others             81.0       5664       5395     1226     12366.0
#      Under Trials     3343.0     105762      91102    22831    223038.0
# 2003 Convicts          185.0      35656      43260    12665     91766.0
#      Detenus            26.0       1249       2334      399      4008.0
#      Others              6.0       2016      10877      188     13087.0
#      Under Trials     1935.0     102441      90320    22962    217658.0
# ...

# %%
totalAgeYearType = grpYearType['Total(Age)']
totalAgeYearType
# Out:
# Year  Type
# 2001  Convicts         75663.0
#       Detenus           3288.0
#       Others           13867.0
#       Under Trials    220817.0
# 2002  Convicts         82121.0
#       Detenus           4832.0
#       Others           12366.0
#       Under Trials    223038.0
# 2003  Convicts         91766.0
#       Detenus           4008.0
#       Others           13087.0
#       Under Trials    217658.0
# 2004  Convicts         98527.0
#       Detenus           4494.0
#       Others           11240.0
#       Under Trials    217130.0
# 2005  Convicts        108572.0
#       Detenus           2542.0
#       Others           10178.0
#       Under Trials    237076.0
# 2006  Convicts        116675.0
#       Detenus           2275.0
#       Others            9077.0
#       Under Trials    245244.0
# 2007  Convicts        120115.0
#       Detenus           4687.0
#       Others             867.0
#       Under Trials    250727.0
# 2008  Convicts        123307.0
# ...

# %%
# List of Convicts
listgrpYearTypeC = totalAgeYearType.take(np.arange(0,13*4,4))
listgrpYearTypeC
# Out:
# Year  Type
# 2001  Convicts     75663.0
# 2002  Convicts     82121.0
# 2003  Convicts     91766.0
# 2004  Convicts     98527.0
# 2005  Convicts    108572.0
# 2006  Convicts    116675.0
# 2007  Convicts    120115.0
# 2008  Convicts    123307.0
# 2009  Convicts    123941.0
# 2010  Convicts    125789.0
# 2011  Convicts    128592.0
# 2012  Convicts    127789.0
# 2013  Convicts    129608.0
# Name: Total(Age), dtype: float64

# %%
# List of Detenus
listgrpYearTypeD = totalAgeYearType.take(np.arange(1,13*4,4))
listgrpYearTypeD
# Out:
# Year  Type
# 2001  Detenus    3288.0
# 2002  Detenus    4832.0
# 2003  Detenus    4008.0
# 2004  Detenus    4494.0
# 2005  Detenus    2542.0
# 2006  Detenus    2275.0
# 2007  Detenus    4687.0
# 2008  Detenus    2978.0
# 2009  Detenus    2232.0
# 2010  Detenus    2325.0
# 2011  Detenus    2450.0
# 2012  Detenus    1922.0
# 2013  Detenus    3113.0
# Name: Total(Age), dtype: float64

# %%
# List of Others
listgrpYearTypeO = totalAgeYearType.take(np.arange(2,13*4,4))
listgrpYearTypeO
# Out:
# Year  Type
# 2001  Others    13867.0
# 2002  Others    12366.0
# 2003  Others    13087.0
# 2004  Others    11240.0
# 2005  Others    10178.0
# 2006  Others     9077.0
# 2007  Others      867.0
# 2008  Others      540.0
# 2009  Others      592.0
# 2010  Others      786.0
# 2011  Others      684.0
# 2012  Others      567.0
# 2013  Others      768.0
# Name: Total(Age), dtype: float64

# %%
# List of Under Trials
listgrpYearTypeUT = totalAgeYearType.take(np.arange(3,13*4,4))
listgrpYearTypeUT
# Out:
# Year  Type
# 2001  Under Trials    220817.0
# 2002  Under Trials    223038.0
# 2003  Under Trials    217658.0
# 2004  Under Trials    217130.0
# 2005  Under Trials    237076.0
# 2006  Under Trials    245244.0
# 2007  Under Trials    250727.0
# 2008  Under Trials    257928.0
# 2009  Under Trials    250204.0
# 2010  Under Trials    240098.0
# 2011  Under Trials    241200.0
# 2012  Under Trials    254857.0
# 2013  Under Trials    278503.0
# Name: Total(Age), dtype: float64

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), listgrpYearTypeC, label='Convicts')
plt.plot(np.arange(2001,2014), listgrpYearTypeD, label='Detenus')
plt.plot(np.arange(2001,2014), listgrpYearTypeO, label='Others')
plt.plot(np.arange(2001,2014), listgrpYearTypeUT, label='Under Trials')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 16-18 on grounds of Gender over different years.

# %%
grpYearGen
# Out:
#              Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Year Gender
# 2001 Female       62.0       3959       5566     1507     11094.0
#      Male       5690.0     135788     131223    29840    302541.0
# 2002 Female       82.0       4393       6131     1441     12047.0
#      Male       3795.0     142813     131050    32652    310310.0
# 2003 Female       16.0       4226       7026     1512     12780.0
#      Male       2136.0     137136     139765    34702    313739.0
# 2004 Female       26.0       4190       7005     1749     12970.0
#      Male       1029.0     136925     144798    35669    318421.0
# 2005 Female       12.0       4964       6954     2056     13986.0
#      Male       1358.0     149593     152766    40665    344382.0
# 2006 Female       14.0       4807       7575     2261     14657.0
#      Male        649.0     150057     163942    43966    358614.0
# 2007 Female       47.0       5731       7461     2162     15401.0
# ...

# %%
YearGenage16_18F = grpYearGen['Age 16-18'].take(np.arange(0,26,2))
YearGenage16_18F
# Out:
# Year  Gender
# 2001  Female    62.0
# 2002  Female    82.0
# 2003  Female    16.0
# 2004  Female    26.0
# 2005  Female    12.0
# 2006  Female    14.0
# 2007  Female    47.0
# 2008  Female     8.0
# 2009  Female     4.0
# 2010  Female     8.0
# 2011  Female     1.0
# 2012  Female    13.0
# 2013  Female     0.0
# Name: Age 16-18, dtype: float64

# %%
YearGenage16_18M = grpYearGen['Age 16-18'].take(np.arange(1,26,2))
YearGenage16_18M
# Out:
# Year  Gender
# 2001  Male      5690.0
# 2002  Male      3795.0
# 2003  Male      2136.0
# 2004  Male      1029.0
# 2005  Male      1358.0
# 2006  Male       649.0
# 2007  Male       448.0
# 2008  Male       166.0
# 2009  Male        60.0
# 2010  Male       249.0
# 2011  Male        94.0
# 2012  Male        93.0
# 2013  Male        33.0
# Name: Age 16-18, dtype: float64

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), YearGenage16_18F, label='Female')
plt.plot(np.arange(2001,2014), YearGenage16_18M, label='Male')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 18-30 on grounds of Gender over different years.

# %%
YearGenage18_30F = grpYearGen['Age 18-30'].take(np.arange(0,26,2))
YearGenage18_30F
# Out:
# Year  Gender
# 2001  Female    3959
# 2002  Female    4393
# 2003  Female    4226
# 2004  Female    4190
# 2005  Female    4964
# 2006  Female    4807
# 2007  Female    5731
# 2008  Female    5356
# 2009  Female    5368
# 2010  Female    5083
# 2011  Female    5541
# 2012  Female    5533
# 2013  Female    6021
# Name: Age 18-30, dtype: int64

# %%
YearGenage18_30M = grpYearGen['Age 18-30'].take(np.arange(1,26,2))
YearGenage18_30M
# Out:
# Year  Gender
# 2001  Male      135788
# 2002  Male      142813
# 2003  Male      137136
# 2004  Male      136925
# 2005  Male      149593
# 2006  Male      150057
# 2007  Male      156998
# 2008  Male      154724
# 2009  Male      157830
# 2010  Male      154961
# 2011  Male      158606
# 2012  Male      157161
# 2013  Male      167853
# Name: Age 18-30, dtype: int64

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), YearGenage18_30F, label='Female')
plt.plot(np.arange(2001,2014), YearGenage18_30M, label='Male')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %%
N = 13
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, YearGenage18_30F, width, label='Female')
plt.bar(ind+width, YearGenage18_30M, width, label='Male')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, np.arange(2001,2014), rotation = 'vertical')
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 30-50 on grounds of Gender over different years.

# %%
YearGenage30_50M = grpYearGen['Age 30-50'].take(np.arange(1,26,2))
YearGenage30_50M
# Out:
# Year  Gender
# 2001  Male      131223
# 2002  Male      131050
# 2003  Male      139765
# 2004  Male      144798
# 2005  Male      152766
# 2006  Male      163942
# 2007  Male      163413
# 2008  Male      169233
# 2009  Male      158671
# 2010  Male      154570
# 2011  Male      153371
# 2012  Male      161071
# 2013  Male      175353
# Name: Age 30-50, dtype: int64

# %%
YearGenage30_50F = grpYearGen['Age 30-50'].take(np.arange(0,26,2))
YearGenage30_50F
# Out:
# Year  Gender
# 2001  Female    5566
# 2002  Female    6131
# 2003  Female    7026
# 2004  Female    7005
# 2005  Female    6954
# 2006  Female    7575
# 2007  Female    7461
# 2008  Female    8126
# 2009  Female    7607
# 2010  Female    7474
# 2011  Female    7855
# 2012  Female    8400
# 2013  Female    8933
# Name: Age 30-50, dtype: int64

# %%
N = 13
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, YearGenage30_50F, width, label='Female')
plt.bar(ind+width, YearGenage30_50M, width, label='Male')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, np.arange(2001,2014), rotation = 'vertical')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), YearGenage30_50F, label='Female')
plt.plot(np.arange(2001,2014), YearGenage30_50M, label='Male')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 50+ on grounds of Gender over different years.

# %%
YearGenage50F = grpYearGen['Age 50+'].take(np.arange(0,26,2))
YearGenage50F
# Out:
# Year  Gender
# 2001  Female    1507
# 2002  Female    1441
# 2003  Female    1512
# 2004  Female    1749
# 2005  Female    2056
# 2006  Female    2261
# 2007  Female    2162
# 2008  Female    2439
# 2009  Female    2427
# 2010  Female    2472
# 2011  Female    2627
# 2012  Female    3005
# 2013  Female    3234
# Name: Age 50+, dtype: int64

# %%
YearGenage50M = grpYearGen['Age 50+'].take(np.arange(1,26,2))
YearGenage50M
# Out:
# Year  Gender
# 2001  Male      29840
# 2002  Male      32652
# 2003  Male      34702
# 2004  Male      35669
# 2005  Male      40665
# 2006  Male      43966
# 2007  Male      40136
# 2008  Male      44701
# 2009  Male      45002
# 2010  Male      44181
# 2011  Male      44831
# 2012  Male      49859
# 2013  Male      50565
# Name: Age 50+, dtype: int64

# %%
N = 13
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, YearGenage50F, width, label='Female')
plt.bar(ind+width, YearGenage50M, width, label='Male')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, np.arange(2001,2014), rotation = 'vertical')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), YearGenage50F, label='Female')
plt.plot(np.arange(2001,2014), YearGenage50M, label='Male')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 16-18 on grounds of Type(Convicts, Detenus etc) over different years.

# %%
grpYearType
# Out:
#                    Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Year Type
# 2001 Convicts          449.0      30258      35196     9760     75663.0
#      Detenus            14.0       1594       1554      126      3288.0
#      Others             75.0       5859       6953      980     13867.0
#      Under Trials     5214.0     102036      93086    20481    220817.0
# 2002 Convicts          401.0      33603      38475     9642     82121.0
#      Detenus            52.0       2177       2209      394      4832.0
#      Others             81.0       5664       5395     1226     12366.0
#      Under Trials     3343.0     105762      91102    22831    223038.0
# 2003 Convicts          185.0      35656      43260    12665     91766.0
#      Detenus            26.0       1249       2334      399      4008.0
#      Others              6.0       2016      10877      188     13087.0
#      Under Trials     1935.0     102441      90320    22962    217658.0
# ...

# %%
# List of Convicts
listYearType16_18C = grpYearType['Age 16-18'].take(np.arange(0,13*4,4))
listYearType16_18C
# Out:
# Year  Type
# 2001  Convicts    449.0
# 2002  Convicts    401.0
# 2003  Convicts    185.0
# 2004  Convicts    120.0
# 2005  Convicts     94.0
# 2006  Convicts     64.0
# 2007  Convicts     75.0
# 2008  Convicts      4.0
# 2009  Convicts      0.0
# 2010  Convicts      0.0
# 2011  Convicts      0.0
# 2012  Convicts      0.0
# 2013  Convicts     27.0
# Name: Age 16-18, dtype: float64

# %%
# List of Detenus
listYearType16_18D = grpYearType['Age 16-18'].take(np.arange(1,13*4,4))
listYearType16_18D
# Out:
# Year  Type
# 2001  Detenus    14.0
# 2002  Detenus    52.0
# 2003  Detenus    26.0
# 2004  Detenus    44.0
# 2005  Detenus    13.0
# 2006  Detenus    29.0
# 2007  Detenus    37.0
# 2008  Detenus    42.0
# 2009  Detenus    49.0
# 2010  Detenus    31.0
# 2011  Detenus    29.0
# 2012  Detenus     0.0
# 2013  Detenus     0.0
# Name: Age 16-18, dtype: float64

# %%
# List of Others
listYearType16_18O = grpYearType['Age 16-18'].take(np.arange(2,13*4,4))
listYearType16_18O
# Out:
# Year  Type
# 2001  Others    75.0
# 2002  Others    81.0
# 2003  Others     6.0
# 2004  Others    20.0
# 2005  Others    21.0
# 2006  Others     3.0
# 2007  Others    26.0
# 2008  Others     2.0
# 2009  Others     1.0
# 2010  Others     0.0
# 2011  Others     1.0
# 2012  Others    15.0
# 2013  Others     3.0
# Name: Age 16-18, dtype: float64

# %%
# List of Under Trials
listYearType16_18UT = grpYearType['Age 16-18'].take(np.arange(0,13*4,4))
listYearType16_18UT
# Out:
# Year  Type
# 2001  Convicts    449.0
# 2002  Convicts    401.0
# 2003  Convicts    185.0
# 2004  Convicts    120.0
# 2005  Convicts     94.0
# 2006  Convicts     64.0
# 2007  Convicts     75.0
# 2008  Convicts      4.0
# 2009  Convicts      0.0
# 2010  Convicts      0.0
# 2011  Convicts      0.0
# 2012  Convicts      0.0
# 2013  Convicts     27.0
# Name: Age 16-18, dtype: float64

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), listYearType16_18C, label='Convicts')
plt.plot(np.arange(2001,2014), listYearType16_18D, label='Detenus')
plt.plot(np.arange(2001,2014), listYearType16_18O, label='Others')
plt.plot(np.arange(2001,2014), listYearType16_18UT, label='Under Trials')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 18-30 on grounds of Type(Convicts, Detenus etc) over different years.

# %%
# List of Convicts
listYearType18_30C = grpYearType['Age 18-30'].take(np.arange(0,13*4,4))
listYearType18_30C
# Out:
# Year  Type
# 2001  Convicts    30258
# 2002  Convicts    33603
# 2003  Convicts    35656
# 2004  Convicts    36657
# 2005  Convicts    39279
# 2006  Convicts    44371
# 2007  Convicts    41995
# 2008  Convicts    42268
# 2009  Convicts    44770
# 2010  Convicts    45924
# 2011  Convicts    46480
# 2012  Convicts    43622
# 2013  Convicts    41572
# Name: Age 18-30, dtype: int64

# %%
# List of Detenus
listYearType18_30D = grpYearType['Age 18-30'].take(np.arange(1,13*4,4))
listYearType18_30D
# Out:
# Year  Type
# 2001  Detenus    1594
# 2002  Detenus    2177
# 2003  Detenus    1249
# 2004  Detenus    1660
# 2005  Detenus    1092
# 2006  Detenus     990
# 2007  Detenus    2280
# 2008  Detenus    1172
# 2009  Detenus     973
# 2010  Detenus    1120
# 2011  Detenus    1074
# 2012  Detenus     855
# 2013  Detenus    1586
# Name: Age 18-30, dtype: int64

# %%
# List of Others
listYearType18_30O = grpYearType['Age 18-30'].take(np.arange(2,13*4,4))
listYearType18_30O
# Out:
# Year  Type
# 2001  Others    5859
# 2002  Others    5664
# 2003  Others    2016
# 2004  Others    2197
# 2005  Others    4169
# 2006  Others    3168
# 2007  Others     367
# 2008  Others     226
# 2009  Others     217
# 2010  Others     322
# 2011  Others     286
# 2012  Others     233
# 2013  Others     345
# Name: Age 18-30, dtype: int64

# %%
# List of Under Trials
listYearType18_30UT = grpYearType['Age 18-30'].take(np.arange(3,13*4,4))
listYearType18_30UT
# Out:
# Year  Type
# 2001  Under Trials    102036
# 2002  Under Trials    105762
# 2003  Under Trials    102441
# 2004  Under Trials    100601
# 2005  Under Trials    110017
# 2006  Under Trials    106335
# 2007  Under Trials    118087
# 2008  Under Trials    116414
# 2009  Under Trials    117238
# 2010  Under Trials    112678
# 2011  Under Trials    116307
# 2012  Under Trials    117984
# 2013  Under Trials    130371
# Name: Age 18-30, dtype: int64

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), listYearType18_30C, label='Convicts')
plt.plot(np.arange(2001,2014), listYearType18_30D, label='Detenus')
plt.plot(np.arange(2001,2014), listYearType18_30O, label='Others')
plt.plot(np.arange(2001,2014), listYearType18_30UT, label='Under Trials')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 30-50 on grounds of Type(Convicts, Detenus etc) over different years.

# %%
# List of Convicts
listYearType30_50C = grpYearType['Age 30-50'].take(np.arange(0,13*4,4))
listYearType30_50C
# Out:
# Year  Type
# 2001  Convicts    35196
# 2002  Convicts    38475
# 2003  Convicts    43260
# 2004  Convicts    47431
# 2005  Convicts    52535
# 2006  Convicts    56479
# 2007  Convicts    59578
# 2008  Convicts    61675
# 2009  Convicts    59869
# 2010  Convicts    59745
# 2011  Convicts    61133
# 2012  Convicts    62135
# 2013  Convicts    64996
# Name: Age 30-50, dtype: int64

# %%
# List of Detenus
listYearType30_50D = grpYearType['Age 30-50'].take(np.arange(1,13*4,4))
listYearType30_50D
# Out:
# Year  Type
# 2001  Detenus    1554
# 2002  Detenus    2209
# 2003  Detenus    2334
# 2004  Detenus    2475
# 2005  Detenus    1093
# 2006  Detenus    1064
# 2007  Detenus    1892
# 2008  Detenus    1460
# 2009  Detenus    1071
# 2010  Detenus    1027
# 2011  Detenus    1176
# 2012  Detenus     878
# 2013  Detenus    1387
# Name: Age 30-50, dtype: int64

# %%
# List of Others
listYearType30_50O = grpYearType['Age 30-50'].take(np.arange(2,13*4,4))
listYearType30_50O
# Out:
# Year  Type
# 2001  Others     6953
# 2002  Others     5395
# 2003  Others    10877
# 2004  Others     8297
# 2005  Others     4957
# 2006  Others     4935
# 2007  Others      384
# 2008  Others      269
# 2009  Others      329
# 2010  Others      383
# 2011  Others      308
# 2012  Others      267
# 2013  Others      348
# Name: Age 30-50, dtype: int64

# %%
# List of Under Trials
listYearType30_50UT = grpYearType['Age 30-50'].take(np.arange(3,13*4,4))
listYearType30_50UT
# Out:
# Year  Type
# 2001  Under Trials     93086
# 2002  Under Trials     91102
# 2003  Under Trials     90320
# 2004  Under Trials     93600
# 2005  Under Trials    101135
# 2006  Under Trials    109039
# 2007  Under Trials    109020
# 2008  Under Trials    113955
# 2009  Under Trials    105009
# 2010  Under Trials    100889
# 2011  Under Trials     98609
# 2012  Under Trials    106191
# 2013  Under Trials    117555
# Name: Age 30-50, dtype: int64

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), listYearType30_50C, label='Convicts')
plt.plot(np.arange(2001,2014), listYearType30_50D, label='Detenus')
plt.plot(np.arange(2001,2014), listYearType30_50O, label='Others')
plt.plot(np.arange(2001,2014), listYearType30_50UT, label='Under Trials')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 50+ on grounds of Type(Convicts, Detenus etc) over different years.

# %%
# List of Convicts
listYearType50C = grpYearType['Age 50+'].take(np.arange(0,13*4,4))
listYearType50C
# Out:
# Year  Type
# 2001  Convicts     9760
# 2002  Convicts     9642
# 2003  Convicts    12665
# 2004  Convicts    14319
# 2005  Convicts    16664
# 2006  Convicts    15761
# 2007  Convicts    18467
# 2008  Convicts    19360
# 2009  Convicts    19302
# 2010  Convicts    20120
# 2011  Convicts    20979
# 2012  Convicts    22032
# 2013  Convicts    23013
# Name: Age 50+, dtype: int64

# %%
# List of Detenus
listYearType50D = grpYearType['Age 50+'].take(np.arange(1,13*4,4))
listYearType50D
# Out:
# Year  Type
# 2001  Detenus    126
# 2002  Detenus    394
# 2003  Detenus    399
# 2004  Detenus    315
# 2005  Detenus    344
# 2006  Detenus    192
# 2007  Detenus    478
# 2008  Detenus    304
# 2009  Detenus    139
# 2010  Detenus    147
# 2011  Detenus    171
# 2012  Detenus    189
# 2013  Detenus    140
# Name: Age 50+, dtype: int64

# %%
# List of Others
listYearType50O = grpYearType['Age 50+'].take(np.arange(2,13*4,4))
listYearType50O
# Out:
# Year  Type
# 2001  Others     980
# 2002  Others    1226
# 2003  Others     188
# 2004  Others     726
# 2005  Others    1031
# 2006  Others     971
# 2007  Others      90
# 2008  Others      43
# 2009  Others      45
# 2010  Others      81
# 2011  Others      89
# 2012  Others      52
# 2013  Others      72
# Name: Age 50+, dtype: int64

# %%
# List of Under Trials
listYearType50UT = grpYearType['Age 50+'].take(np.arange(3,13*4,4))
listYearType50UT
# Out:
# Year  Type
# 2001  Under Trials    20481
# 2002  Under Trials    22831
# 2003  Under Trials    22962
# 2004  Under Trials    22058
# 2005  Under Trials    24682
# 2006  Under Trials    29303
# 2007  Under Trials    23263
# 2008  Under Trials    27433
# 2009  Under Trials    27943
# 2010  Under Trials    26305
# 2011  Under Trials    26219
# 2012  Under Trials    30591
# 2013  Under Trials    30574
# Name: Age 50+, dtype: int64

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), listYearType50C, label='Convicts')
plt.plot(np.arange(2001,2014), listYearType50D, label='Detenus')
plt.plot(np.arange(2001,2014), listYearType50O, label='Others')
plt.plot(np.arange(2001,2014), listYearType50UT, label='Under Trials')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of Number of Prisoners of age 16-18 on grounds of Category and Gender.

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %%
grpCatGen = df.groupby(['Category', 'Gender']).sum().drop(['is_state', 'Year'], axis='columns')
grpCatGen
# Out:
#                    Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Category   Gender
# Foreigners Female       59.0       3466       3019      496      7040.0
#            Male        268.0      23495      23093     4057     50913.0
# Indians    Female      234.0      61706      93094    28396    183430.0
#            Male      15532.0    1936950    1976133   532712   4461327.0

# %%
listCatGen16_18For = grpCatGen['Age 16-18'].take([0,1])
listCatGen16_18For
# Out:
# Category    Gender
# Foreigners  Female     59.0
#             Male      268.0
# Name: Age 16-18, dtype: float64

# %%
listCatGen16_18IN = grpCatGen['Age 16-18'].take([2,3])
listCatGen16_18IN
# Out:
# Category  Gender
# Indians   Female      234.0
#           Male      15532.0
# Name: Age 16-18, dtype: float64

# %%
N = 2
ind = np.arange(N)
width = 0.3

plt.bar(ind, listCatGen16_18For, width, label='Foreigners')
plt.bar(ind+width, listCatGen16_18IN, width, label='Indians')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Female', 'Male'])
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of Number of Prisoners of age 18-30 on grounds of Category and Gender.

# %%
listCatGen18_30For = grpCatGen['Age 18-30'].take([0,1])
listCatGen18_30For
# Out:
# Category    Gender
# Foreigners  Female     3466
#             Male      23495
# Name: Age 18-30, dtype: int64

# %%
listCatGen18_30IN = grpCatGen['Age 18-30'].take([2,3])
listCatGen18_30IN
# Out:
# Category  Gender
# Indians   Female      61706
#           Male      1936950
# Name: Age 18-30, dtype: int64

# %%
N = 2
ind = np.arange(N)
width = 0.3

plt.bar(ind, listCatGen18_30For, width, label='Foreigners')
plt.bar(ind+width, listCatGen18_30IN, width, label='Indians')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Female', 'Male'])
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of Number of Prisoners of age 30-50 on grounds of Category and Gender.

# %%
listCatGen30_50For = grpCatGen['Age 30-50'].take([0,1])
listCatGen30_50For
# Out:
# Category    Gender
# Foreigners  Female     3019
#             Male      23093
# Name: Age 30-50, dtype: int64

# %%
listCatGen30_50IN = grpCatGen['Age 30-50'].take([2,3])
listCatGen30_50IN
# Out:
# Category  Gender
# Indians   Female      93094
#           Male      1976133
# Name: Age 30-50, dtype: int64

# %%
N = 2
ind = np.arange(N)
width = 0.3

plt.bar(ind, listCatGen30_50For, width, label='Foreigners')
plt.bar(ind+width, listCatGen30_50IN, width, label='Indians')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Female', 'Male'])
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of Number of Prisoners of age 50+ on grounds of Category and Gender.

# %%
listCatGen50For = grpCatGen['Age 50+'].take([0,1])
listCatGen50For
# Out:
# Category    Gender
# Foreigners  Female     496
#             Male      4057
# Name: Age 50+, dtype: int64

# %%
listCatGen50IN = grpCatGen['Age 50+'].take([2,3])
listCatGen50IN
# Out:
# Category  Gender
# Indians   Female     28396
#           Male      532712
# Name: Age 50+, dtype: int64

# %%
N = 2
ind = np.arange(N)
width = 0.3

plt.bar(ind, listCatGen50For, width, label='Foreigners')
plt.bar(ind+width, listCatGen50IN, width, label='Indians')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Female', 'Male'])
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of Number of Prisoners of age 16-18 on grounds of Category and Type.

# %%
grpCatType = df.groupby(['Category', 'Type']).sum().drop(['is_state', 'Year'], axis='columns')
grpCatType
# Out:
#                          Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Category   Type
# Foreigners Convicts           97.0       7704       8773     1735     18309.0
#            Detenus             8.0        594        683      104      1389.0
#            Others              5.0       1278        785      245      2313.0
#            Under Trials      217.0      17385      15871     2469     35942.0
# Indians    Convicts         1322.0     518751     693734   220349   1434156.0
#            Detenus           358.0      17228      18937     3234     39757.0
#            Others            249.0      23791      42917     5349     72306.0
#            Under Trials    13837.0    1438886    1313639   332176   3098538.0

# %%
listCatType16_18For = grpCatType['Age 16-18'].take([0,1,2,3])
listCatType16_18For
# Out:
# Category    Type
# Foreigners  Convicts         97.0
#             Detenus           8.0
#             Others            5.0
#             Under Trials    217.0
# Name: Age 16-18, dtype: float64

# %%
listCatType16_18IN = grpCatType['Age 16-18'].take([4,5,6,7])
listCatType16_18IN
# Out:
# Category  Type
# Indians   Convicts         1322.0
#           Detenus           358.0
#           Others            249.0
#           Under Trials    13837.0
# Name: Age 16-18, dtype: float64

# %%
N = 4
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, listCatType16_18For, width, label='Foreigners')
plt.bar(ind+width, listCatType16_18IN, width, label='Indians')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Convicts', 'Detenus', 'Others', 'Under Trials'])
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of Number of Prisoners of age 18-30 on grounds of Category and Type.

# %%
listCatType18_30For = grpCatType['Age 18-30'].take([0,1,2,3])
listCatType18_30For
# Out:
# Category    Type
# Foreigners  Convicts         7704
#             Detenus           594
#             Others           1278
#             Under Trials    17385
# Name: Age 18-30, dtype: int64

# %%
listCatType18_30IN = grpCatType['Age 18-30'].take([4,5,6,7])
listCatType18_30IN
# Out:
# Category  Type
# Indians   Convicts         518751
#           Detenus           17228
#           Others            23791
#           Under Trials    1438886
# Name: Age 18-30, dtype: int64

# %%
N = 4
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, listCatType18_30For, width, label='Foreigners')
plt.bar(ind+width, listCatType18_30IN, width, label='Indians')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Convicts', 'Detenus', 'Others', 'Under Trials'])
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of Number of Prisoners of age 30-50 on grounds of Category and Type.

# %%
listCatType30_50For = grpCatType['Age 30-50'].take([0,1,2,3])
listCatType30_50For
# Out:
# Category    Type
# Foreigners  Convicts         8773
#             Detenus           683
#             Others            785
#             Under Trials    15871
# Name: Age 30-50, dtype: int64

# %%
listCatType30_50IN = grpCatType['Age 30-50'].take([4,5,6,7])
listCatType30_50IN
# Out:
# Category  Type
# Indians   Convicts         693734
#           Detenus           18937
#           Others            42917
#           Under Trials    1313639
# Name: Age 30-50, dtype: int64

# %%
N = 4
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, listCatType30_50For, width, label='Foreigners')
plt.bar(ind+width, listCatType30_50IN, width, label='Indians')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Convicts', 'Detenus', 'Others', 'Under Trials'])
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of Number of Prisoners of age 50+ on grounds of Category and Type.

# %%
listCatType50For = grpCatType['Age 50+'].take([0,1,2,3])
listCatType50For
# Out:
# Category    Type
# Foreigners  Convicts        1735
#             Detenus          104
#             Others           245
#             Under Trials    2469
# Name: Age 50+, dtype: int64

# %%
listCatType50IN = grpCatType['Age 50+'].take([4,5,6,7])
listCatType50IN
# Out:
# Category  Type
# Indians   Convicts        220349
#           Detenus           3234
#           Others            5349
#           Under Trials    332176
# Name: Age 50+, dtype: int64

# %%
N = 4
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, listCatType50For, width, label='Foreigners')
plt.bar(ind+width, listCatType50IN, width, label='Indians')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Convicts', 'Detenus', 'Others', 'Under Trials'])
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of Number of Prisoners on grounds of Category over different Years.

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %%
grpCatYear = df.groupby(['Year', 'Category']).sum().drop('is_state', axis='columns')
grpCatYear
# Out:
#                  Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Year Category
# 2001 Foreigners       24.0        997       1137      169      2327.0
#      Indians        5728.0     138750     135652    31178    311308.0
# 2002 Foreigners       64.0       1359       1288      147      2858.0
#      Indians        3813.0     145847     135893    33946    319499.0
# 2003 Foreigners       14.0        991       1078      122      2205.0
#      Indians        2138.0     140371     145713    36092    324314.0
# 2004 Foreigners       34.0       1198       1119      190      2541.0
#      Indians        1021.0     139917     150684    37228    328850.0
# 2005 Foreigners       32.0       1804       1779      306      3921.0
#      Indians        1338.0     152753     157941    42415    354447.0
# 2006 Foreigners       27.0       1676       1803      272      3778.0
#      Indians         636.0     153188     169714    45955    369493.0
# ...

# %%
listCatYearFor = grpCatYear['Total(Age)'].take(np.arange(0,26,2))
listCatYearFor
# Out:
# Year  Category
# 2001  Foreigners    2327.0
# 2002  Foreigners    2858.0
# 2003  Foreigners    2205.0
# 2004  Foreigners    2541.0
# 2005  Foreigners    3921.0
# 2006  Foreigners    3778.0
# 2007  Foreigners    4695.0
# 2008  Foreigners    5226.0
# 2009  Foreigners    5262.0
# 2010  Foreigners    5108.0
# 2011  Foreigners    6023.0
# 2012  Foreigners    6844.0
# 2013  Foreigners    7165.0
# Name: Total(Age), dtype: float64

# %%
listCatYearIN = grpCatYear['Total(Age)'].take(np.arange(1,27,2))
listCatYearIN
# Out:
# Year  Category
# 2001  Indians     311308.0
# 2002  Indians     319499.0
# 2003  Indians     324314.0
# 2004  Indians     328850.0
# 2005  Indians     354447.0
# 2006  Indians     369493.0
# 2007  Indians     371701.0
# 2008  Indians     379527.0
# 2009  Indians     371707.0
# 2010  Indians     363890.0
# 2011  Indians     366903.0
# 2012  Indians     378291.0
# 2013  Indians     404827.0
# Name: Total(Age), dtype: float64

# %%
N = 13
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, listCatYearFor, width, label='Foreigners')
plt.bar(ind+width, listCatYearIN, width, label='Indians')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), listCatYearIN, label='Indians')
plt.plot(np.arange(2001,2014), listCatYearFor, label='Foreigners')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 16-18 on grounds of Category over different Years.

# %%
listCatYear16_18For = grpCatYear['Age 16-18'].take(np.arange(0,26,2))
listCatYear16_18For
# Out:
# Year  Category
# 2001  Foreigners     24.0
# 2002  Foreigners     64.0
# 2003  Foreigners     14.0
# 2004  Foreigners     34.0
# 2005  Foreigners     32.0
# 2006  Foreigners     27.0
# 2007  Foreigners    117.0
# 2008  Foreigners     10.0
# 2009  Foreigners      4.0
# 2010  Foreigners      0.0
# 2011  Foreigners      1.0
# 2012  Foreigners      0.0
# 2013  Foreigners      0.0
# Name: Age 16-18, dtype: float64

# %%
listCatYear16_18IN = grpCatYear['Age 16-18'].take(np.arange(1,27,2))
listCatYear16_18IN
# Out:
# Year  Category
# 2001  Indians     5728.0
# 2002  Indians     3813.0
# 2003  Indians     2138.0
# 2004  Indians     1021.0
# 2005  Indians     1338.0
# 2006  Indians      636.0
# 2007  Indians      378.0
# 2008  Indians      164.0
# 2009  Indians       60.0
# 2010  Indians      257.0
# 2011  Indians       94.0
# 2012  Indians      106.0
# 2013  Indians       33.0
# Name: Age 16-18, dtype: float64

# %%
N = 13
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, listCatYear16_18For, width, label='Foreigners')
plt.bar(ind+width, listCatYear16_18IN, width, label='Indians')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), listCatYear16_18IN, label='Indians')
plt.plot(np.arange(2001,2014), listCatYear16_18For, label='Foreigners')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 18-30 on grounds of Category over different Years.

# %%
listCatYear18_30For = grpCatYear['Age 18-30'].take(np.arange(0,26,2))
listCatYear18_30For
# Out:
# Year  Category
# 2001  Foreigners     997
# 2002  Foreigners    1359
# 2003  Foreigners     991
# 2004  Foreigners    1198
# 2005  Foreigners    1804
# 2006  Foreigners    1676
# 2007  Foreigners    2102
# 2008  Foreigners    2345
# 2009  Foreigners    2555
# 2010  Foreigners    2294
# 2011  Foreigners    2860
# 2012  Foreigners    3206
# 2013  Foreigners    3574
# Name: Age 18-30, dtype: int64

# %%
listCatYear18_30IN = grpCatYear['Age 18-30'].take(np.arange(1,27,2))
listCatYear18_30IN
# Out:
# Year  Category
# 2001  Indians     138750
# 2002  Indians     145847
# 2003  Indians     140371
# 2004  Indians     139917
# 2005  Indians     152753
# 2006  Indians     153188
# 2007  Indians     160627
# 2008  Indians     157735
# 2009  Indians     160643
# 2010  Indians     157750
# 2011  Indians     161287
# 2012  Indians     159488
# 2013  Indians     170300
# Name: Age 18-30, dtype: int64

# %%
N = 13
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, listCatYear18_30For, width, label='Foreigners')
plt.bar(ind+width, listCatYear18_30IN, width, label='Indians')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), listCatYear18_30IN, label='Indians')
plt.plot(np.arange(2001,2014), listCatYear18_30For, label='Foreigners')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 30-50 on grounds of Category over different Years.

# %%
listCatYear30_50For = grpCatYear['Age 30-50'].take(np.arange(0,26,2))
listCatYear30_50For
# Out:
# Year  Category
# 2001  Foreigners    1137
# 2002  Foreigners    1288
# 2003  Foreigners    1078
# 2004  Foreigners    1119
# 2005  Foreigners    1779
# 2006  Foreigners    1803
# 2007  Foreigners    2165
# 2008  Foreigners    2362
# 2009  Foreigners    2268
# 2010  Foreigners    2332
# 2011  Foreigners    2654
# 2012  Foreigners    3103
# 2013  Foreigners    3024
# Name: Age 30-50, dtype: int64

# %%
listCatYear30_50IN = grpCatYear['Age 30-50'].take(np.arange(1,27,2))
listCatYear30_50IN
# Out:
# Year  Category
# 2001  Indians     135652
# 2002  Indians     135893
# 2003  Indians     145713
# 2004  Indians     150684
# 2005  Indians     157941
# 2006  Indians     169714
# 2007  Indians     168709
# 2008  Indians     174997
# 2009  Indians     164010
# 2010  Indians     159712
# 2011  Indians     158572
# 2012  Indians     166368
# 2013  Indians     181262
# Name: Age 30-50, dtype: int64

# %%
N = 13
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, listCatYear30_50For, width, label='Foreigners')
plt.bar(ind+width, listCatYear30_50IN, width, label='Indians')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), listCatYear30_50IN, label='Indians')
plt.plot(np.arange(2001,2014), listCatYear30_50For, label='Foreigners')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 50+ on grounds of Category over different Years.

# %%
listCatYear50For = grpCatYear['Age 50+'].take(np.arange(0,26,2))
listCatYear50For
# Out:
# Year  Category
# 2001  Foreigners    169
# 2002  Foreigners    147
# 2003  Foreigners    122
# 2004  Foreigners    190
# 2005  Foreigners    306
# 2006  Foreigners    272
# 2007  Foreigners    311
# 2008  Foreigners    509
# 2009  Foreigners    435
# 2010  Foreigners    482
# 2011  Foreigners    508
# 2012  Foreigners    535
# 2013  Foreigners    567
# Name: Age 50+, dtype: int64

# %%
listCatYear50IN = grpCatYear['Age 50+'].take(np.arange(1,27,2))
listCatYear50IN
# Out:
# Year  Category
# 2001  Indians     31178
# 2002  Indians     33946
# 2003  Indians     36092
# 2004  Indians     37228
# 2005  Indians     42415
# 2006  Indians     45955
# 2007  Indians     41987
# 2008  Indians     46631
# 2009  Indians     46994
# 2010  Indians     46171
# 2011  Indians     46950
# 2012  Indians     52329
# 2013  Indians     53232
# Name: Age 50+, dtype: int64

# %%
N = 13
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, listCatYear50For, width, label='Foreigners')
plt.bar(ind+width, listCatYear50IN, width, label='Indians')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(np.arange(2001,2014), listCatYear50IN, label='Indians')
plt.plot(np.arange(2001,2014), listCatYear50For, label='Foreigners')

plt.ylabel("Number", size=13)

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners on grounds of Type and Gender.

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %%
grpTypeGen = df.groupby(['Type', 'Gender']).sum().drop(['is_state', 'Year'], axis='columns')
grpTypeGen
# Out:
#                      Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Type         Gender
# Convicts     Female       11.0      14266      27245    10492     52014.0
#              Male       1408.0     512189     675262   211592   1400451.0
# Detenus      Female        3.0        492       1200      227      1922.0
#              Male        363.0      17330      18420     3111     39224.0
# Others       Female       15.0       1843       5854     1010      8722.0
#              Male        239.0      23226      37848     4584     65897.0
# Under Trials Female      264.0      48571      61814    17163    127812.0
#              Male      13790.0    1407700    1267696   317482   3006668.0

# %%
grpTypeGenF = grpTypeGen['Total(Age)'].take(np.arange(0,8,2))
grpTypeGenF
# Out:
# Type          Gender
# Convicts      Female     52014.0
# Detenus       Female      1922.0
# Others        Female      8722.0
# Under Trials  Female    127812.0
# Name: Total(Age), dtype: float64

# %%
grpTypeGenM = grpTypeGen['Total(Age)'].take(np.arange(1,9,2))
grpTypeGenM
# Out:
# Type          Gender
# Convicts      Male      1400451.0
# Detenus       Male        39224.0
# Others        Male        65897.0
# Under Trials  Male      3006668.0
# Name: Total(Age), dtype: float64

# %%
N = 4
ind = np.arange(N)
width = 0.3

plt.bar(ind, grpTypeGenM, width, label='Male')
plt.bar(ind+width, grpTypeGenF, width, label='Female')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Convicts', 'Detenus', 'Others', 'Under Trials'])
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 16-18 on grounds of Type and Gender.

# %%
listTypeGen16_18F = grpTypeGen['Age 16-18'].take(np.arange(0,8,2))
listTypeGen16_18F
# Out:
# Type          Gender
# Convicts      Female     11.0
# Detenus       Female      3.0
# Others        Female     15.0
# Under Trials  Female    264.0
# Name: Age 16-18, dtype: float64

# %%
listTypeGen16_18M = grpTypeGen['Age 16-18'].take(np.arange(1,9,2))
listTypeGen16_18M
# Out:
# Type          Gender
# Convicts      Male       1408.0
# Detenus       Male        363.0
# Others        Male        239.0
# Under Trials  Male      13790.0
# Name: Age 16-18, dtype: float64

# %%
N = 4
ind = np.arange(N)
width = 0.3

plt.bar(ind, listTypeGen16_18M, width, label='Male')
plt.bar(ind+width, listTypeGen16_18F, width, label='Female')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Convicts', 'Detenus', 'Others', 'Under Trials'])
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 18-30 on grounds of Type and Gender.

# %%
listTypeGen18_30F = grpTypeGen['Age 18-30'].take(np.arange(0,8,2))
listTypeGen18_30F
# Out:
# Type          Gender
# Convicts      Female    14266
# Detenus       Female      492
# Others        Female     1843
# Under Trials  Female    48571
# Name: Age 18-30, dtype: int64

# %%
listTypeGen18_30M = grpTypeGen['Age 18-30'].take(np.arange(1,9,2))
listTypeGen18_30M
# Out:
# Type          Gender
# Convicts      Male       512189
# Detenus       Male        17330
# Others        Male        23226
# Under Trials  Male      1407700
# Name: Age 18-30, dtype: int64

# %%
N = 4
ind = np.arange(N)
width = 0.3

plt.bar(ind, listTypeGen18_30M, width, label='Male')
plt.bar(ind+width, listTypeGen18_30F, width, label='Female')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Convicts', 'Detenus', 'Others', 'Under Trials'])
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 30-50 on grounds of Type and Gender.

# %%
listTypeGen30_50F = grpTypeGen['Age 30-50'].take(np.arange(0,8,2))
listTypeGen30_50F
# Out:
# Type          Gender
# Convicts      Female    27245
# Detenus       Female     1200
# Others        Female     5854
# Under Trials  Female    61814
# Name: Age 30-50, dtype: int64

# %%
listTypeGen30_50M = grpTypeGen['Age 30-50'].take(np.arange(1,9,2))
listTypeGen30_50M
# Out:
# Type          Gender
# Convicts      Male       675262
# Detenus       Male        18420
# Others        Male        37848
# Under Trials  Male      1267696
# Name: Age 30-50, dtype: int64

# %%
N = 4
ind = np.arange(N)
width = 0.3

plt.bar(ind, listTypeGen30_50M, width, label='Male')
plt.bar(ind+width, listTypeGen30_50F, width, label='Female')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Convicts', 'Detenus', 'Others', 'Under Trials'])
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 50+ on grounds of Type and Gender.

# %%
listTypeGen50F = grpTypeGen['Age 50+'].take(np.arange(0,8,2))
listTypeGen50F
# Out:
# Type          Gender
# Convicts      Female    10492
# Detenus       Female      227
# Others        Female     1010
# Under Trials  Female    17163
# Name: Age 50+, dtype: int64

# %%
listTypeGen50M = grpTypeGen['Age 50+'].take(np.arange(1,9,2))
listTypeGen50M
# Out:
# Type          Gender
# Convicts      Male      211592
# Detenus       Male        3111
# Others        Male        4584
# Under Trials  Male      317482
# Name: Age 50+, dtype: int64

# %%
N = 4
ind = np.arange(N)
width = 0.3

plt.bar(ind, listTypeGen50M, width, label='Male')
plt.bar(ind+width, listTypeGen50F, width, label='Female')

plt.ylabel("Number", size=13)

plt.xticks(ind + width / 2, ['Convicts', 'Detenus', 'Others', 'Under Trials'])
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners on grounds of Category & Gender over years.

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %%
grpCatGenYear = df.groupby(['Year', 'Category', 'Gender']).sum().drop('is_state', axis='columns')
grpCatGenYear
# Out:
#                         Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Year Category   Gender
# 2001 Foreigners Female        0.0         68         86       11       165.0
#                 Male         24.0        929       1051      158      2162.0
#      Indians    Female       62.0       3891       5480     1496     10929.0
#                 Male       5666.0     134859     130172    29682    300379.0
# 2002 Foreigners Female       18.0        140        118        8       284.0
#                 Male         46.0       1219       1170      139      2574.0
#      Indians    Female       64.0       4253       6013     1433     11763.0
#                 Male       3749.0     141594     129880    32513    307736.0
# 2003 Foreigners Female        0.0        178        180       17       375.0
#                 Male         14.0        813        898      105      1830.0
#      Indians    Female       16.0       4048       6846     1495     12405.0
# ...

# %%
listCatGenYearForF = grpCatGenYear['Total(Age)'].take(np.arange(0,13*4,4))
listCatGenYearForF
# Out:
# Year  Category    Gender
# 2001  Foreigners  Female    165.0
# 2002  Foreigners  Female    284.0
# 2003  Foreigners  Female    375.0
# 2004  Foreigners  Female    462.0
# 2005  Foreigners  Female    626.0
# 2006  Foreigners  Female    586.0
# 2007  Foreigners  Female    708.0
# 2008  Foreigners  Female    789.0
# 2009  Foreigners  Female    702.0
# 2010  Foreigners  Female    441.0
# 2011  Foreigners  Female    566.0
# 2012  Foreigners  Female    678.0
# 2013  Foreigners  Female    658.0
# Name: Total(Age), dtype: float64

# %%
listCatGenYearForM = grpCatGenYear['Total(Age)'].take(np.arange(1,53,4))
listCatGenYearForM
# Out:
# Year  Category    Gender
# 2001  Foreigners  Male      2162.0
# 2002  Foreigners  Male      2574.0
# 2003  Foreigners  Male      1830.0
# 2004  Foreigners  Male      2079.0
# 2005  Foreigners  Male      3295.0
# 2006  Foreigners  Male      3192.0
# 2007  Foreigners  Male      3987.0
# 2008  Foreigners  Male      4437.0
# 2009  Foreigners  Male      4560.0
# 2010  Foreigners  Male      4667.0
# 2011  Foreigners  Male      5457.0
# 2012  Foreigners  Male      6166.0
# 2013  Foreigners  Male      6507.0
# Name: Total(Age), dtype: float64

# %%
listCatGenYearINF = grpCatGenYear['Total(Age)'].take(np.arange(2,53,4))
listCatGenYearINF
# Out:
# Year  Category  Gender
# 2001  Indians   Female    10929.0
# 2002  Indians   Female    11763.0
# 2003  Indians   Female    12405.0
# 2004  Indians   Female    12508.0
# 2005  Indians   Female    13360.0
# 2006  Indians   Female    14071.0
# 2007  Indians   Female    14693.0
# 2008  Indians   Female    15140.0
# 2009  Indians   Female    14704.0
# 2010  Indians   Female    14596.0
# 2011  Indians   Female    15458.0
# 2012  Indians   Female    16273.0
# 2013  Indians   Female    17530.0
# Name: Total(Age), dtype: float64

# %%
listCatGenYearINM = grpCatGenYear['Total(Age)'].take(np.arange(3,53,4))
listCatGenYearINM
# Out:
# Year  Category  Gender
# 2001  Indians   Male      300379.0
# 2002  Indians   Male      307736.0
# 2003  Indians   Male      311909.0
# 2004  Indians   Male      316342.0
# 2005  Indians   Male      341087.0
# 2006  Indians   Male      355422.0
# 2007  Indians   Male      357008.0
# 2008  Indians   Male      364387.0
# 2009  Indians   Male      357003.0
# 2010  Indians   Male      349294.0
# 2011  Indians   Male      351445.0
# 2012  Indians   Male      362018.0
# 2013  Indians   Male      387297.0
# Name: Total(Age), dtype: float64

# %%
N = 13
ind = np.arange(N)
width = 0.2

plt.figure(figsize=(10,5))

plt.bar(ind, listCatGenYearForF, width, label='Foreigner(Female)')
plt.bar(ind+width, listCatGenYearINF, width, label='Indian(Female)')
plt.bar(ind+width+width, listCatGenYearForM, width, label='Foreigner(Male)')
plt.bar(ind+width+width+width, listCatGenYearINM, width, label='Indian(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Indian(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.3

plt.figure(figsize=(10,5))

plt.bar(ind, listCatGenYearForF, width, label='Foreigner(Female)')
plt.bar(ind+width, listCatGenYearINF, width, label='Indian(Female)')
plt.bar(ind+width+width, listCatGenYearForM, width, label='Foreigner(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 16-18 on grounds of Category & Gender over years.

# %%
listCatGenYear16_18ForF = grpCatGenYear['Age 16-18'].take(np.arange(0,13*4,4))
listCatGenYear16_18ForF
# Out:
# Year  Category    Gender
# 2001  Foreigners  Female     0.0
# 2002  Foreigners  Female    18.0
# 2003  Foreigners  Female     0.0
# 2004  Foreigners  Female     2.0
# 2005  Foreigners  Female     1.0
# 2006  Foreigners  Female     1.0
# 2007  Foreigners  Female    32.0
# 2008  Foreigners  Female     4.0
# 2009  Foreigners  Female     1.0
# 2010  Foreigners  Female     0.0
# 2011  Foreigners  Female     0.0
# 2012  Foreigners  Female     0.0
# 2013  Foreigners  Female     0.0
# Name: Age 16-18, dtype: float64

# %%
listCatGenYear16_18ForM = grpCatGenYear['Age 16-18'].take(np.arange(1,53,4))
listCatGenYear16_18ForM
# Out:
# Year  Category    Gender
# 2001  Foreigners  Male      24.0
# 2002  Foreigners  Male      46.0
# 2003  Foreigners  Male      14.0
# 2004  Foreigners  Male      32.0
# 2005  Foreigners  Male      31.0
# 2006  Foreigners  Male      26.0
# 2007  Foreigners  Male      85.0
# 2008  Foreigners  Male       6.0
# 2009  Foreigners  Male       3.0
# 2010  Foreigners  Male       0.0
# 2011  Foreigners  Male       1.0
# 2012  Foreigners  Male       0.0
# 2013  Foreigners  Male       0.0
# Name: Age 16-18, dtype: float64

# %%
listCatGenYear16_18INF = grpCatGenYear['Age 16-18'].take(np.arange(2,13*4,4))
listCatGenYear16_18INF
# Out:
# Year  Category  Gender
# 2001  Indians   Female    62.0
# 2002  Indians   Female    64.0
# 2003  Indians   Female    16.0
# 2004  Indians   Female    24.0
# 2005  Indians   Female    11.0
# 2006  Indians   Female    13.0
# 2007  Indians   Female    15.0
# 2008  Indians   Female     4.0
# 2009  Indians   Female     3.0
# 2010  Indians   Female     8.0
# 2011  Indians   Female     1.0
# 2012  Indians   Female    13.0
# 2013  Indians   Female     0.0
# Name: Age 16-18, dtype: float64

# %%
listCatGenYear16_18INM = grpCatGenYear['Age 16-18'].take(np.arange(3,13*4,4))
listCatGenYear16_18INM
# Out:
# Year  Category  Gender
# 2001  Indians   Male      5666.0
# 2002  Indians   Male      3749.0
# 2003  Indians   Male      2122.0
# 2004  Indians   Male       997.0
# 2005  Indians   Male      1327.0
# 2006  Indians   Male       623.0
# 2007  Indians   Male       363.0
# 2008  Indians   Male       160.0
# 2009  Indians   Male        57.0
# 2010  Indians   Male       249.0
# 2011  Indians   Male        93.0
# 2012  Indians   Male        93.0
# 2013  Indians   Male        33.0
# Name: Age 16-18, dtype: float64

# %%
N = 13
ind = np.arange(N)
width = 0.2

plt.figure(figsize=(10,5))

plt.bar(ind, listCatGenYear16_18ForF, width, label='Foreigner(Female)')
plt.bar(ind+width, listCatGenYear16_18INF, width, label='Indian(Female)')
plt.bar(ind+width+width, listCatGenYear16_18ForM, width, label='Foreigner(Male)')
plt.bar(ind+width+width+width, listCatGenYear16_18INM, width, label='Indian(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Indian(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.2

plt.figure(figsize=(10,5))

plt.bar(ind, listCatGenYear16_18ForF, width, label='Foreigner(Female)')
plt.bar(ind+width, listCatGenYear16_18INF, width, label='Indian(Female)')
plt.bar(ind+width+width, listCatGenYear16_18ForM, width, label='Foreigner(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 18-30 on grounds of Category & Gender over years.

# %%
listCatGenYear18_30ForF = grpCatGenYear['Age 18-30'].take(np.arange(0,13*4,4))
listCatGenYear18_30ForF
# Out:
# Year  Category    Gender
# 2001  Foreigners  Female     68
# 2002  Foreigners  Female    140
# 2003  Foreigners  Female    178
# 2004  Foreigners  Female    259
# 2005  Foreigners  Female    313
# 2006  Foreigners  Female    288
# 2007  Foreigners  Female    394
# 2008  Foreigners  Female    417
# 2009  Foreigners  Female    365
# 2010  Foreigners  Female    193
# 2011  Foreigners  Female    266
# 2012  Foreigners  Female    290
# 2013  Foreigners  Female    295
# Name: Age 18-30, dtype: int64

# %%
listCatGenYear18_30ForM = grpCatGenYear['Age 18-30'].take(np.arange(1,53,4))
listCatGenYear18_30ForM
# Out:
# Year  Category    Gender
# 2001  Foreigners  Male       929
# 2002  Foreigners  Male      1219
# 2003  Foreigners  Male       813
# 2004  Foreigners  Male       939
# 2005  Foreigners  Male      1491
# 2006  Foreigners  Male      1388
# 2007  Foreigners  Male      1708
# 2008  Foreigners  Male      1928
# 2009  Foreigners  Male      2190
# 2010  Foreigners  Male      2101
# 2011  Foreigners  Male      2594
# 2012  Foreigners  Male      2916
# 2013  Foreigners  Male      3279
# Name: Age 18-30, dtype: int64

# %%
listCatGenYear18_30INF = grpCatGenYear['Age 18-30'].take(np.arange(2,53,4))
listCatGenYear18_30INF
# Out:
# Year  Category  Gender
# 2001  Indians   Female    3891
# 2002  Indians   Female    4253
# 2003  Indians   Female    4048
# 2004  Indians   Female    3931
# 2005  Indians   Female    4651
# 2006  Indians   Female    4519
# 2007  Indians   Female    5337
# 2008  Indians   Female    4939
# 2009  Indians   Female    5003
# 2010  Indians   Female    4890
# 2011  Indians   Female    5275
# 2012  Indians   Female    5243
# 2013  Indians   Female    5726
# Name: Age 18-30, dtype: int64

# %%
listCatGenYear18_30INM = grpCatGenYear['Age 18-30'].take(np.arange(3,53,4))
listCatGenYear18_30INM
# Out:
# Year  Category  Gender
# 2001  Indians   Male      134859
# 2002  Indians   Male      141594
# 2003  Indians   Male      136323
# 2004  Indians   Male      135986
# 2005  Indians   Male      148102
# 2006  Indians   Male      148669
# 2007  Indians   Male      155290
# 2008  Indians   Male      152796
# 2009  Indians   Male      155640
# 2010  Indians   Male      152860
# 2011  Indians   Male      156012
# 2012  Indians   Male      154245
# 2013  Indians   Male      164574
# Name: Age 18-30, dtype: int64

# %%
N = 13
ind = np.arange(N)
width = 0.2

plt.figure(figsize=(10,5))

plt.bar(ind, listCatGenYear18_30ForF, width, label='Foreigner(Female)')
plt.bar(ind+width, listCatGenYear18_30INF, width, label='Indian(Female)')
plt.bar(ind+width+width, listCatGenYear18_30ForM, width, label='Foreigner(Male)')
plt.bar(ind+width+width+width, listCatGenYear18_30INM, width, label='Indian(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Indian(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.2

plt.figure(figsize=(10,5))

plt.bar(ind, listCatGenYear18_30ForF, width, label='Foreigner(Female)')
plt.bar(ind+width, listCatGenYear18_30INF, width, label='Indian(Female)')
plt.bar(ind+width+width, listCatGenYear18_30ForM, width, label='Foreigner(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 30-50 on grounds of Category & Gender over years.

# %%
listCatGenYear30_50ForF = grpCatGenYear['Age 30-50'].take(np.arange(0,13*4,4))
listCatGenYear30_50ForF
# Out:
# Year  Category    Gender
# 2001  Foreigners  Female     86
# 2002  Foreigners  Female    118
# 2003  Foreigners  Female    180
# 2004  Foreigners  Female    170
# 2005  Foreigners  Female    269
# 2006  Foreigners  Female    256
# 2007  Foreigners  Female    244
# 2008  Foreigners  Female    310
# 2009  Foreigners  Female    287
# 2010  Foreigners  Female    199
# 2011  Foreigners  Female    262
# 2012  Foreigners  Female    342
# 2013  Foreigners  Female    296
# Name: Age 30-50, dtype: int64

# %%
listCatGenYear30_50ForM = grpCatGenYear['Age 30-50'].take(np.arange(1,53,4))
listCatGenYear30_50ForM
# Out:
# Year  Category    Gender
# 2001  Foreigners  Male      1051
# 2002  Foreigners  Male      1170
# 2003  Foreigners  Male       898
# 2004  Foreigners  Male       949
# 2005  Foreigners  Male      1510
# 2006  Foreigners  Male      1547
# 2007  Foreigners  Male      1921
# 2008  Foreigners  Male      2052
# 2009  Foreigners  Male      1981
# 2010  Foreigners  Male      2133
# 2011  Foreigners  Male      2392
# 2012  Foreigners  Male      2761
# 2013  Foreigners  Male      2728
# Name: Age 30-50, dtype: int64

# %%
listCatGenYear30_50INF = grpCatGenYear['Age 30-50'].take(np.arange(2,53,4))
listCatGenYear30_50INF
# Out:
# Year  Category  Gender
# 2001  Indians   Female    5480
# 2002  Indians   Female    6013
# 2003  Indians   Female    6846
# 2004  Indians   Female    6835
# 2005  Indians   Female    6685
# 2006  Indians   Female    7319
# 2007  Indians   Female    7217
# 2008  Indians   Female    7816
# 2009  Indians   Female    7320
# 2010  Indians   Female    7275
# 2011  Indians   Female    7593
# 2012  Indians   Female    8058
# 2013  Indians   Female    8637
# Name: Age 30-50, dtype: int64

# %%
listCatGenYear30_50INM = grpCatGenYear['Age 30-50'].take(np.arange(3,53,4))
listCatGenYear30_50INM
# Out:
# Year  Category  Gender
# 2001  Indians   Male      130172
# 2002  Indians   Male      129880
# 2003  Indians   Male      138867
# 2004  Indians   Male      143849
# 2005  Indians   Male      151256
# 2006  Indians   Male      162395
# 2007  Indians   Male      161492
# 2008  Indians   Male      167181
# 2009  Indians   Male      156690
# 2010  Indians   Male      152437
# 2011  Indians   Male      150979
# 2012  Indians   Male      158310
# 2013  Indians   Male      172625
# Name: Age 30-50, dtype: int64

# %%
N = 13
ind = np.arange(N)
width = 0.2

plt.figure(figsize=(10,5))

plt.bar(ind, listCatGenYear30_50ForF, width, label='Foreigner(Female)')
plt.bar(ind+width, listCatGenYear30_50INF, width, label='Indian(Female)')
plt.bar(ind+width+width, listCatGenYear30_50ForM, width, label='Foreigner(Male)')
plt.bar(ind+width+width+width, listCatGenYear30_50INM, width, label='Indian(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Indian(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.2

plt.figure(figsize=(10,5))

plt.bar(ind, listCatGenYear30_50ForF, width, label='Foreigner(Female)')
plt.bar(ind+width, listCatGenYear30_50INF, width, label='Indian(Female)')
plt.bar(ind+width+width, listCatGenYear30_50ForM, width, label='Foreigner(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 50+ on grounds of Category & Gender over years.

# %%
listCatGenYear50ForF = grpCatGenYear['Age 50+'].take(np.arange(0,13*4,4))
listCatGenYear50ForF
# Out:
# Year  Category    Gender
# 2001  Foreigners  Female    11
# 2002  Foreigners  Female     8
# 2003  Foreigners  Female    17
# 2004  Foreigners  Female    31
# 2005  Foreigners  Female    43
# 2006  Foreigners  Female    41
# 2007  Foreigners  Female    38
# 2008  Foreigners  Female    58
# 2009  Foreigners  Female    49
# 2010  Foreigners  Female    49
# 2011  Foreigners  Female    38
# 2012  Foreigners  Female    46
# 2013  Foreigners  Female    67
# Name: Age 50+, dtype: int64

# %%
listCatGenYear50ForM = grpCatGenYear['Age 50+'].take(np.arange(1,53,4))
listCatGenYear50ForM
# Out:
# Year  Category    Gender
# 2001  Foreigners  Male      158
# 2002  Foreigners  Male      139
# 2003  Foreigners  Male      105
# 2004  Foreigners  Male      159
# 2005  Foreigners  Male      263
# 2006  Foreigners  Male      231
# 2007  Foreigners  Male      273
# 2008  Foreigners  Male      451
# 2009  Foreigners  Male      386
# 2010  Foreigners  Male      433
# 2011  Foreigners  Male      470
# 2012  Foreigners  Male      489
# 2013  Foreigners  Male      500
# Name: Age 50+, dtype: int64

# %%
listCatGenYear50INF = grpCatGenYear['Age 50+'].take(np.arange(2,53,4))
listCatGenYear50INF
# Out:
# Year  Category  Gender
# 2001  Indians   Female    1496
# 2002  Indians   Female    1433
# 2003  Indians   Female    1495
# 2004  Indians   Female    1718
# 2005  Indians   Female    2013
# 2006  Indians   Female    2220
# 2007  Indians   Female    2124
# 2008  Indians   Female    2381
# 2009  Indians   Female    2378
# 2010  Indians   Female    2423
# 2011  Indians   Female    2589
# 2012  Indians   Female    2959
# 2013  Indians   Female    3167
# Name: Age 50+, dtype: int64

# %%
listCatGenYear50INM = grpCatGenYear['Age 50+'].take(np.arange(3,53,4))
listCatGenYear50INM
# Out:
# Year  Category  Gender
# 2001  Indians   Male      29682
# 2002  Indians   Male      32513
# 2003  Indians   Male      34597
# 2004  Indians   Male      35510
# 2005  Indians   Male      40402
# 2006  Indians   Male      43735
# 2007  Indians   Male      39863
# 2008  Indians   Male      44250
# 2009  Indians   Male      44616
# 2010  Indians   Male      43748
# 2011  Indians   Male      44361
# 2012  Indians   Male      49370
# 2013  Indians   Male      50065
# Name: Age 50+, dtype: int64

# %%
N = 13
ind = np.arange(N)
width = 0.2

plt.figure(figsize=(10,5))

plt.bar(ind, listCatGenYear50ForF, width, label='Foreigner(Female)')
plt.bar(ind+width, listCatGenYear50INF, width, label='Indian(Female)')
plt.bar(ind+width+width, listCatGenYear50ForM, width, label='Foreigner(Male)')
plt.bar(ind+width+width+width, listCatGenYear50INM, width, label='Indian(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Indian(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.2

plt.figure(figsize=(10,5))

plt.bar(ind, listCatGenYear50ForF, width, label='Foreigner(Female)')
plt.bar(ind+width, listCatGenYear50INF, width, label='Indian(Female)')
plt.bar(ind+width+width, listCatGenYear50ForM, width, label='Foreigner(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners on grounds of Type and Gender over Years.

# %%
df.head()
# Out:
#       State_Name  is_state  Year    Category      Type  Gender  Age 16-18  \
# 0  A & N Islands         0  2001  Foreigners  Convicts  Female        0.0
# 1  A & N Islands         0  2001  Foreigners  Convicts    Male        0.0
# 2  A & N Islands         0  2001  Foreigners   Detenus  Female        0.0
# 3  A & N Islands         0  2001  Foreigners   Detenus    Male        0.0
# 4  A & N Islands         0  2001  Foreigners    Others  Female        0.0
#
#    Age 18-30  Age 30-50  Age 50+  Total(Age)
# 0          0          0        0         0.0
# 1         12        139        2       153.0
# 2          0          0        0         0.0
# 3          0          0        0         0.0
# 4          0          0        0         0.0

# %%
grpTypeGenYear = df.groupby(['Year', 'Type', 'Gender']).sum().drop('is_state', axis='columns')
grpTypeGenYear
# Out:
#                           Age 16-18  Age 18-30  Age 30-50  Age 50+  Total(Age)
# Year Type         Gender
# 2001 Convicts     Female        0.0        627       1180      382      2189.0
#                   Male        449.0      29631      34016     9378     73474.0
#      Detenus      Female        0.0         67        185       20       272.0
#                   Male         14.0       1527       1369      106      3016.0
#      Others       Female        6.0        355        929      161      1451.0
# ...                             ...        ...        ...      ...         ...
# 2013 Detenus      Male          0.0       1570       1319      126      3015.0
#      Others       Female        0.0         23         26        8        57.0
#                   Male          3.0        322        322       64       711.0
#      Under Trials Female        0.0       4637       6092     1959     12688.0
#                   Male          3.0     125734     111463    28615    265815.0
# ...

# %%
listTypeGenYearCF = grpTypeGenYear['Total(Age)'].take(np.arange(0,104,8))
listTypeGenYearCF
# Out:
# Year  Type      Gender
# 2001  Convicts  Female    2189.0
# 2002  Convicts  Female    2662.0
# 2003  Convicts  Female    3370.0
# 2004  Convicts  Female    3358.0
# 2005  Convicts  Female    3543.0
# 2006  Convicts  Female    3904.0
# 2007  Convicts  Female    4058.0
# 2008  Convicts  Female    4393.0
# 2009  Convicts  Female    4588.0
# 2010  Convicts  Female    4632.0
# 2011  Convicts  Female    4959.0
# 2012  Convicts  Female    5013.0
# 2013  Convicts  Female    5345.0
# Name: Total(Age), dtype: float64

# %%
listTypeGenYearCM = grpTypeGenYear['Total(Age)'].take(np.arange(1,104,8))
listTypeGenYearCM
# Out:
# Year  Type      Gender
# 2001  Convicts  Male       73474.0
# 2002  Convicts  Male       79459.0
# 2003  Convicts  Male       88396.0
# 2004  Convicts  Male       95169.0
# 2005  Convicts  Male      105029.0
# 2006  Convicts  Male      112771.0
# 2007  Convicts  Male      116057.0
# 2008  Convicts  Male      118914.0
# 2009  Convicts  Male      119353.0
# 2010  Convicts  Male      121157.0
# 2011  Convicts  Male      123633.0
# 2012  Convicts  Male      122776.0
# 2013  Convicts  Male      124263.0
# Name: Total(Age), dtype: float64

# %%
listTypeGenYearDF = grpTypeGenYear['Total(Age)'].take(np.arange(2,104,8))
listTypeGenYearDF
# Out:
# Year  Type     Gender
# 2001  Detenus  Female    272.0
# 2002  Detenus  Female    256.0
# 2003  Detenus  Female    167.0
# 2004  Detenus  Female    204.0
# 2005  Detenus  Female     83.0
# 2006  Detenus  Female     96.0
# 2007  Detenus  Female    270.0
# 2008  Detenus  Female     92.0
# 2009  Detenus  Female    101.0
# 2010  Detenus  Female    106.0
# 2011  Detenus  Female     87.0
# 2012  Detenus  Female     90.0
# 2013  Detenus  Female     98.0
# Name: Total(Age), dtype: float64

# %%
listTypeGenYearDM = grpTypeGenYear['Total(Age)'].take(np.arange(3,104,8))
listTypeGenYearDM
# Out:
# Year  Type     Gender
# 2001  Detenus  Male      3016.0
# 2002  Detenus  Male      4576.0
# 2003  Detenus  Male      3841.0
# 2004  Detenus  Male      4290.0
# 2005  Detenus  Male      2459.0
# 2006  Detenus  Male      2179.0
# 2007  Detenus  Male      4417.0
# 2008  Detenus  Male      2886.0
# 2009  Detenus  Male      2131.0
# 2010  Detenus  Male      2219.0
# 2011  Detenus  Male      2363.0
# 2012  Detenus  Male      1832.0
# 2013  Detenus  Male      3015.0
# Name: Total(Age), dtype: float64

# %%
listTypeGenYearOF = grpTypeGenYear['Total(Age)'].take(np.arange(4,104,8))
listTypeGenYearOF
# Out:
# Year  Type    Gender
# 2001  Others  Female    1451.0
# 2002  Others  Female    1368.0
# 2003  Others  Female    1529.0
# 2004  Others  Female    1556.0
# 2005  Others  Female    1290.0
# 2006  Others  Female    1202.0
# 2007  Others  Female      60.0
# 2008  Others  Female      42.0
# 2009  Others  Female      30.0
# 2010  Others  Female      47.0
# 2011  Others  Female      44.0
# 2012  Others  Female      46.0
# 2013  Others  Female      57.0
# Name: Total(Age), dtype: float64

# %%
listTypeGenYearOM = grpTypeGenYear['Total(Age)'].take(np.arange(5,104,8))
listTypeGenYearOM
# Out:
# Year  Type    Gender
# 2001  Others  Male      12416.0
# 2002  Others  Male      10998.0
# 2003  Others  Male      11558.0
# 2004  Others  Male       9684.0
# 2005  Others  Male       8888.0
# 2006  Others  Male       7875.0
# 2007  Others  Male        807.0
# 2008  Others  Male        498.0
# 2009  Others  Male        562.0
# 2010  Others  Male        739.0
# 2011  Others  Male        640.0
# 2012  Others  Male        521.0
# 2013  Others  Male        711.0
# Name: Total(Age), dtype: float64

# %%
listTypeGenYearUTF = grpTypeGenYear['Total(Age)'].take(np.arange(6,105,8))
listTypeGenYearUTF
# Out:
# Year  Type          Gender
# 2001  Under Trials  Female     7182.0
# 2002  Under Trials  Female     7761.0
# 2003  Under Trials  Female     7714.0
# 2004  Under Trials  Female     7852.0
# 2005  Under Trials  Female     9070.0
# 2006  Under Trials  Female     9455.0
# 2007  Under Trials  Female    11013.0
# 2008  Under Trials  Female    11402.0
# 2009  Under Trials  Female    10687.0
# 2010  Under Trials  Female    10252.0
# 2011  Under Trials  Female    10934.0
# 2012  Under Trials  Female    11802.0
# 2013  Under Trials  Female    12688.0
# Name: Total(Age), dtype: float64

# %%
listTypeGenYearUTM = grpTypeGenYear['Total(Age)'].take(np.arange(7,105,8))
listTypeGenYearUTM
# Out:
# Year  Type          Gender
# 2001  Under Trials  Male      213635.0
# 2002  Under Trials  Male      215277.0
# 2003  Under Trials  Male      209944.0
# 2004  Under Trials  Male      209278.0
# 2005  Under Trials  Male      228006.0
# 2006  Under Trials  Male      235789.0
# 2007  Under Trials  Male      239714.0
# 2008  Under Trials  Male      246526.0
# 2009  Under Trials  Male      239517.0
# 2010  Under Trials  Male      229846.0
# 2011  Under Trials  Male      230266.0
# 2012  Under Trials  Male      243055.0
# 2013  Under Trials  Male      265815.0
# Name: Total(Age), dtype: float64

# %%
N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(15,6))

plt.bar(ind, listTypeGenYearCF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYearDF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYearOF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYearUTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width, listTypeGenYearCM, width, label='Convicts(Male)')
plt.bar(ind+width+width+width+width+width, listTypeGenYearDM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYearOM, width, label='Others(Male)')
plt.bar(ind+width+width+width+width+width+width+width, listTypeGenYearUTM, width, label='Under Trials(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Under Trials(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(12,6))

plt.bar(ind, listTypeGenYearCF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYearDF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYearOF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYearUTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width, listTypeGenYearCM, width, label='Convicts(Male)')
plt.bar(ind+width+width+width+width+width, listTypeGenYearDM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYearOM, width, label='Others(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Convicts(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(12,6))

plt.bar(ind, listTypeGenYearCF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYearDF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYearOF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYearUTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width+width, listTypeGenYearDM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYearOM, width, label='Others(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 16-18 on grounds of Type and Gender over Years.

# %%
listTypeGenYear16_18CF = grpTypeGenYear['Age 16-18'].take(np.arange(0,104,8))
listTypeGenYear16_18CF
# Out:
# Year  Type      Gender
# 2001  Convicts  Female    0.0
# 2002  Convicts  Female    4.0
# 2003  Convicts  Female    2.0
# 2004  Convicts  Female    1.0
# 2005  Convicts  Female    0.0
# 2006  Convicts  Female    0.0
# 2007  Convicts  Female    4.0
# 2008  Convicts  Female    0.0
# 2009  Convicts  Female    0.0
# 2010  Convicts  Female    0.0
# 2011  Convicts  Female    0.0
# 2012  Convicts  Female    0.0
# 2013  Convicts  Female    0.0
# Name: Age 16-18, dtype: float64

# %%
listTypeGenYear16_18CM = grpTypeGenYear['Age 16-18'].take(np.arange(1,104,8))
listTypeGenYear16_18CM
# Out:
# Year  Type      Gender
# 2001  Convicts  Male      449.0
# 2002  Convicts  Male      397.0
# 2003  Convicts  Male      183.0
# 2004  Convicts  Male      119.0
# 2005  Convicts  Male       94.0
# 2006  Convicts  Male       64.0
# 2007  Convicts  Male       71.0
# 2008  Convicts  Male        4.0
# 2009  Convicts  Male        0.0
# 2010  Convicts  Male        0.0
# 2011  Convicts  Male        0.0
# 2012  Convicts  Male        0.0
# 2013  Convicts  Male       27.0
# Name: Age 16-18, dtype: float64

# %%
listTypeGenYear16_18DF = grpTypeGenYear['Age 16-18'].take(np.arange(2,104,8))
listTypeGenYear16_18DF
# Out:
# Year  Type     Gender
# 2001  Detenus  Female    0.0
# 2002  Detenus  Female    3.0
# 2003  Detenus  Female    0.0
# 2004  Detenus  Female    0.0
# 2005  Detenus  Female    0.0
# 2006  Detenus  Female    0.0
# 2007  Detenus  Female    0.0
# 2008  Detenus  Female    0.0
# 2009  Detenus  Female    0.0
# 2010  Detenus  Female    0.0
# 2011  Detenus  Female    0.0
# 2012  Detenus  Female    0.0
# 2013  Detenus  Female    0.0
# Name: Age 16-18, dtype: float64

# %%
listTypeGenYear16_18DM = grpTypeGenYear['Age 16-18'].take(np.arange(3,104,8))
listTypeGenYear16_18DM
# Out:
# Year  Type     Gender
# 2001  Detenus  Male      14.0
# 2002  Detenus  Male      49.0
# 2003  Detenus  Male      26.0
# 2004  Detenus  Male      44.0
# 2005  Detenus  Male      13.0
# 2006  Detenus  Male      29.0
# 2007  Detenus  Male      37.0
# 2008  Detenus  Male      42.0
# 2009  Detenus  Male      49.0
# 2010  Detenus  Male      31.0
# 2011  Detenus  Male      29.0
# 2012  Detenus  Male       0.0
# 2013  Detenus  Male       0.0
# Name: Age 16-18, dtype: float64

# %%
listTypeGenYear16_18OF = grpTypeGenYear['Age 16-18'].take(np.arange(4,104,8))
listTypeGenYear16_18OF
# Out:
# Year  Type    Gender
# 2001  Others  Female    6.0
# 2002  Others  Female    4.0
# 2003  Others  Female    0.0
# 2004  Others  Female    0.0
# 2005  Others  Female    0.0
# 2006  Others  Female    0.0
# 2007  Others  Female    1.0
# 2008  Others  Female    2.0
# 2009  Others  Female    1.0
# 2010  Others  Female    0.0
# 2011  Others  Female    1.0
# 2012  Others  Female    0.0
# 2013  Others  Female    0.0
# Name: Age 16-18, dtype: float64

# %%
listTypeGenYear16_18OM = grpTypeGenYear['Age 16-18'].take(np.arange(5,104,8))
listTypeGenYear16_18OM
# Out:
# Year  Type    Gender
# 2001  Others  Male      69.0
# 2002  Others  Male      77.0
# 2003  Others  Male       6.0
# 2004  Others  Male      20.0
# 2005  Others  Male      21.0
# 2006  Others  Male       3.0
# 2007  Others  Male      25.0
# 2008  Others  Male       0.0
# 2009  Others  Male       0.0
# 2010  Others  Male       0.0
# 2011  Others  Male       0.0
# 2012  Others  Male      15.0
# 2013  Others  Male       3.0
# Name: Age 16-18, dtype: float64

# %%
listTypeGenYear16_18UTF = grpTypeGenYear['Age 16-18'].take(np.arange(6,104,8))
listTypeGenYear16_18UTF
# Out:
# Year  Type          Gender
# 2001  Under Trials  Female    56.0
# 2002  Under Trials  Female    71.0
# 2003  Under Trials  Female    14.0
# 2004  Under Trials  Female    25.0
# 2005  Under Trials  Female    12.0
# 2006  Under Trials  Female    14.0
# 2007  Under Trials  Female    42.0
# 2008  Under Trials  Female     6.0
# 2009  Under Trials  Female     3.0
# 2010  Under Trials  Female     8.0
# 2011  Under Trials  Female     0.0
# 2012  Under Trials  Female    13.0
# 2013  Under Trials  Female     0.0
# Name: Age 16-18, dtype: float64

# %%
listTypeGenYear16_18UTM = grpTypeGenYear['Age 16-18'].take(np.arange(7,105,8))
listTypeGenYear16_18UTM
# Out:
# Year  Type          Gender
# 2001  Under Trials  Male      5158.0
# 2002  Under Trials  Male      3272.0
# 2003  Under Trials  Male      1921.0
# 2004  Under Trials  Male       846.0
# 2005  Under Trials  Male      1230.0
# 2006  Under Trials  Male       553.0
# 2007  Under Trials  Male       315.0
# 2008  Under Trials  Male       120.0
# 2009  Under Trials  Male        11.0
# 2010  Under Trials  Male       218.0
# 2011  Under Trials  Male        65.0
# 2012  Under Trials  Male        78.0
# 2013  Under Trials  Male         3.0
# Name: Age 16-18, dtype: float64

# %%
N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(15,6))

plt.bar(ind, listTypeGenYear16_18CF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYear16_18DF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYear16_18OF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYear16_18UTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width, listTypeGenYear16_18CM, width, label='Convicts(Male)')
plt.bar(ind+width+width+width+width+width, listTypeGenYear16_18DM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYear16_18OM, width, label='Others(Male)')
plt.bar(ind+width+width+width+width+width+width+width, listTypeGenYear16_18UTM, width, label='Under Trials(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Under Trials(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(15,6))

plt.bar(ind, listTypeGenYear16_18CF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYear16_18DF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYear16_18OF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYear16_18UTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width, listTypeGenYear16_18CM, width, label='Convicts(Male)')
plt.bar(ind+width+width+width+width+width, listTypeGenYear16_18DM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYear16_18OM, width, label='Others(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Convicts(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(15,6))

plt.bar(ind, listTypeGenYear16_18CF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYear16_18DF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYear16_18OF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYear16_18UTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width+width, listTypeGenYear16_18DM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYear16_18OM, width, label='Others(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 18-30 on grounds of Type and Gender over Years.

# %%
listTypeGenYear18_30CF = grpTypeGenYear['Age 18-30'].take(np.arange(0,104,8))
listTypeGenYear18_30CF
# Out:
# Year  Type      Gender
# 2001  Convicts  Female     627
# 2002  Convicts  Female     764
# 2003  Convicts  Female    1060
# 2004  Convicts  Female     953
# 2005  Convicts  Female    1025
# 2006  Convicts  Female    1036
# 2007  Convicts  Female    1161
# 2008  Convicts  Female    1184
# 2009  Convicts  Female    1371
# 2010  Convicts  Female    1252
# 2011  Convicts  Female    1247
# 2012  Convicts  Female    1241
# 2013  Convicts  Female    1345
# Name: Age 18-30, dtype: int64

# %%
listTypeGenYear18_30CM = grpTypeGenYear['Age 18-30'].take(np.arange(1,104,8))
listTypeGenYear18_30CM
# Out:
# Year  Type      Gender
# 2001  Convicts  Male      29631
# 2002  Convicts  Male      32839
# 2003  Convicts  Male      34596
# 2004  Convicts  Male      35704
# 2005  Convicts  Male      38254
# 2006  Convicts  Male      43335
# 2007  Convicts  Male      40834
# 2008  Convicts  Male      41084
# 2009  Convicts  Male      43399
# 2010  Convicts  Male      44672
# 2011  Convicts  Male      45233
# 2012  Convicts  Male      42381
# 2013  Convicts  Male      40227
# Name: Age 18-30, dtype: int64

# %%
listTypeGenYear18_30DF = grpTypeGenYear['Age 18-30'].take(np.arange(2,104,8))
listTypeGenYear18_30DF
# Out:
# Year  Type     Gender
# 2001  Detenus  Female    67
# 2002  Detenus  Female    71
# 2003  Detenus  Female    47
# 2004  Detenus  Female    43
# 2005  Detenus  Female    38
# 2006  Detenus  Female    25
# 2007  Detenus  Female    70
# 2008  Detenus  Female    14
# 2009  Detenus  Female    16
# 2010  Detenus  Female    38
# 2011  Detenus  Female    25
# 2012  Detenus  Female    22
# 2013  Detenus  Female    16
# Name: Age 18-30, dtype: int64

# %%
listTypeGenYear18_30DM = grpTypeGenYear['Age 18-30'].take(np.arange(3,104,8))
listTypeGenYear18_30DM
# Out:
# Year  Type     Gender
# 2001  Detenus  Male      1527
# 2002  Detenus  Male      2106
# 2003  Detenus  Male      1202
# 2004  Detenus  Male      1617
# 2005  Detenus  Male      1054
# 2006  Detenus  Male       965
# 2007  Detenus  Male      2210
# 2008  Detenus  Male      1158
# 2009  Detenus  Male       957
# 2010  Detenus  Male      1082
# 2011  Detenus  Male      1049
# 2012  Detenus  Male       833
# 2013  Detenus  Male      1570
# Name: Age 18-30, dtype: int64

# %%
listTypeGenYear18_30OF = grpTypeGenYear['Age 18-30'].take(np.arange(4,104,8))
listTypeGenYear18_30OF
# Out:
# Year  Type    Gender
# 2001  Others  Female    355
# 2002  Others  Female    495
# 2003  Others  Female     31
# 2004  Others  Female    166
# 2005  Others  Female    326
# 2006  Others  Female    310
# 2007  Others  Female     40
# 2008  Others  Female     24
# 2009  Others  Female     12
# 2010  Others  Female     23
# 2011  Others  Female     15
# 2012  Others  Female     23
# 2013  Others  Female     23
# Name: Age 18-30, dtype: int64

# %%
listTypeGenYear18_30OM = grpTypeGenYear['Age 18-30'].take(np.arange(5,104,8))
listTypeGenYear18_30OM
# Out:
# Year  Type    Gender
# 2001  Others  Male      5504
# 2002  Others  Male      5169
# 2003  Others  Male      1985
# 2004  Others  Male      2031
# 2005  Others  Male      3843
# 2006  Others  Male      2858
# 2007  Others  Male       327
# 2008  Others  Male       202
# 2009  Others  Male       205
# 2010  Others  Male       299
# 2011  Others  Male       271
# 2012  Others  Male       210
# 2013  Others  Male       322
# Name: Age 18-30, dtype: int64

# %%
listTypeGenYear18_30UTF = grpTypeGenYear['Age 18-30'].take(np.arange(6,104,8))
listTypeGenYear18_30UTF
# Out:
# Year  Type          Gender
# 2001  Under Trials  Female    2910
# 2002  Under Trials  Female    3063
# 2003  Under Trials  Female    3088
# 2004  Under Trials  Female    3028
# 2005  Under Trials  Female    3575
# 2006  Under Trials  Female    3436
# 2007  Under Trials  Female    4460
# 2008  Under Trials  Female    4134
# 2009  Under Trials  Female    3969
# 2010  Under Trials  Female    3770
# 2011  Under Trials  Female    4254
# 2012  Under Trials  Female    4247
# 2013  Under Trials  Female    4637
# Name: Age 18-30, dtype: int64

# %%
listTypeGenYear18_30UTM = grpTypeGenYear['Age 18-30'].take(np.arange(7,104,8))
listTypeGenYear18_30UTM
# Out:
# Year  Type          Gender
# 2001  Under Trials  Male       99126
# 2002  Under Trials  Male      102699
# 2003  Under Trials  Male       99353
# 2004  Under Trials  Male       97573
# 2005  Under Trials  Male      106442
# 2006  Under Trials  Male      102899
# 2007  Under Trials  Male      113627
# 2008  Under Trials  Male      112280
# 2009  Under Trials  Male      113269
# 2010  Under Trials  Male      108908
# 2011  Under Trials  Male      112053
# 2012  Under Trials  Male      113737
# 2013  Under Trials  Male      125734
# Name: Age 18-30, dtype: int64

# %%
N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(15,6))

plt.bar(ind, listTypeGenYear18_30CF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYear18_30DF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYear18_30OF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYear18_30UTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width, listTypeGenYear18_30CM, width, label='Convicts(Male)')
plt.bar(ind+width+width+width+width+width, listTypeGenYear18_30DM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYear18_30OM, width, label='Others(Male)')
plt.bar(ind+width+width+width+width+width+width+width, listTypeGenYear18_30UTM, width, label='Under Trials(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Under Convicts(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(15,6))

plt.bar(ind, listTypeGenYear18_30CF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYear18_30DF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYear18_30OF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYear18_30UTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width+width, listTypeGenYear18_30DM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYear18_30OM, width, label='Others(Male)')
plt.bar(ind+width+width+width+width+width+width+width, listTypeGenYear18_30UTM, width, label='Under Trials(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 30-50 on grounds of Type and Gender over Years.

# %%
listTypeGenYear30_50CF = grpTypeGenYear['Age 30-50'].take(np.arange(0,104,8))
listTypeGenYear30_50CF
# Out:
# Year  Type      Gender
# 2001  Convicts  Female    1180
# 2002  Convicts  Female    1452
# 2003  Convicts  Female    1730
# 2004  Convicts  Female    1765
# 2005  Convicts  Female    1838
# 2006  Convicts  Female    2163
# 2007  Convicts  Female    2150
# 2008  Convicts  Female    2253
# 2009  Convicts  Female    2342
# 2010  Convicts  Female    2368
# 2011  Convicts  Female    2615
# 2012  Convicts  Female    2642
# 2013  Convicts  Female    2747
# Name: Age 30-50, dtype: int64

# %%
listTypeGenYear30_50CM = grpTypeGenYear['Age 30-50'].take(np.arange(1,104,8))
listTypeGenYear30_50CM
# Out:
# Year  Type      Gender
# 2001  Convicts  Male      34016
# 2002  Convicts  Male      37023
# 2003  Convicts  Male      41530
# 2004  Convicts  Male      45666
# 2005  Convicts  Male      50697
# 2006  Convicts  Male      54316
# 2007  Convicts  Male      57428
# 2008  Convicts  Male      59422
# 2009  Convicts  Male      57527
# 2010  Convicts  Male      57377
# 2011  Convicts  Male      58518
# 2012  Convicts  Male      59493
# 2013  Convicts  Male      62249
# Name: Age 30-50, dtype: int64

# %%
listTypeGenYear30_50DF = grpTypeGenYear['Age 30-50'].take(np.arange(2,104,8))
listTypeGenYear30_50DF
# Out:
# Year  Type     Gender
# 2001  Detenus  Female    185
# 2002  Detenus  Female    163
# 2003  Detenus  Female     97
# 2004  Detenus  Female    134
# 2005  Detenus  Female     35
# 2006  Detenus  Female     61
# 2007  Detenus  Female    150
# 2008  Detenus  Female     69
# 2009  Detenus  Female     68
# 2010  Detenus  Female     62
# 2011  Detenus  Female     49
# 2012  Detenus  Female     59
# 2013  Detenus  Female     68
# Name: Age 30-50, dtype: int64

# %%
listTypeGenYear30_50DM = grpTypeGenYear['Age 30-50'].take(np.arange(3,104,8))
listTypeGenYear30_50DM
# Out:
# Year  Type     Gender
# 2001  Detenus  Male      1369
# 2002  Detenus  Male      2046
# 2003  Detenus  Male      2237
# 2004  Detenus  Male      2341
# 2005  Detenus  Male      1058
# 2006  Detenus  Male      1003
# 2007  Detenus  Male      1742
# 2008  Detenus  Male      1391
# 2009  Detenus  Male      1003
# 2010  Detenus  Male       965
# 2011  Detenus  Male      1127
# 2012  Detenus  Male       819
# 2013  Detenus  Male      1319
# Name: Age 30-50, dtype: int64

# %%
listTypeGenYear30_50OF = grpTypeGenYear['Age 30-50'].take(np.arange(4,104,8))
listTypeGenYear30_50OF
# Out:
# Year  Type    Gender
# 2001  Others  Female     929
# 2002  Others  Female     746
# 2003  Others  Female    1498
# 2004  Others  Female    1177
# 2005  Others  Female     692
# 2006  Others  Female     677
# 2007  Others  Female      14
# 2008  Others  Female      16
# 2009  Others  Female      17
# 2010  Others  Female      21
# 2011  Others  Female      23
# 2012  Others  Female      18
# 2013  Others  Female      26
# Name: Age 30-50, dtype: int64

# %%
listTypeGenYear30_50OM = grpTypeGenYear['Age 30-50'].take(np.arange(5,104,8))
listTypeGenYear30_50OM
# Out:
# Year  Type    Gender
# 2001  Others  Male      6024
# 2002  Others  Male      4649
# 2003  Others  Male      9379
# 2004  Others  Male      7120
# 2005  Others  Male      4265
# 2006  Others  Male      4258
# 2007  Others  Male       370
# 2008  Others  Male       253
# 2009  Others  Male       312
# 2010  Others  Male       362
# 2011  Others  Male       285
# 2012  Others  Male       249
# 2013  Others  Male       322
# Name: Age 30-50, dtype: int64

# %%
listTypeGenYear30_50UTF = grpTypeGenYear['Age 30-50'].take(np.arange(6,104,8))
listTypeGenYear30_50UTF
# Out:
# Year  Type          Gender
# 2001  Under Trials  Female    3272
# 2002  Under Trials  Female    3770
# 2003  Under Trials  Female    3701
# 2004  Under Trials  Female    3929
# 2005  Under Trials  Female    4389
# 2006  Under Trials  Female    4674
# 2007  Under Trials  Female    5147
# 2008  Under Trials  Female    5788
# 2009  Under Trials  Female    5180
# 2010  Under Trials  Female    5023
# 2011  Under Trials  Female    5168
# 2012  Under Trials  Female    5681
# 2013  Under Trials  Female    6092
# Name: Age 30-50, dtype: int64

# %%
listTypeGenYear30_50UTM = grpTypeGenYear['Age 30-50'].take(np.arange(7,105,8))
listTypeGenYear30_50UTM
# Out:
# Year  Type          Gender
# 2001  Under Trials  Male       89814
# 2002  Under Trials  Male       87332
# 2003  Under Trials  Male       86619
# 2004  Under Trials  Male       89671
# 2005  Under Trials  Male       96746
# 2006  Under Trials  Male      104365
# 2007  Under Trials  Male      103873
# 2008  Under Trials  Male      108167
# 2009  Under Trials  Male       99829
# 2010  Under Trials  Male       95866
# 2011  Under Trials  Male       93441
# 2012  Under Trials  Male      100510
# 2013  Under Trials  Male      111463
# Name: Age 30-50, dtype: int64

# %%
N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(15,6))

plt.bar(ind, listTypeGenYear30_50CF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYear30_50DF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYear30_50OF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYear30_50UTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width, listTypeGenYear30_50CM, width, label='Convicts(Male)')
plt.bar(ind+width+width+width+width+width, listTypeGenYear30_50DM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYear30_50OM, width, label='Others(Male)')
plt.bar(ind+width+width+width+width+width+width+width, listTypeGenYear30_50UTM, width, label='Under Trials(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Under Trials(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(15,6))

plt.bar(ind, listTypeGenYear30_50CF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYear30_50DF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYear30_50OF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYear30_50UTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width, listTypeGenYear30_50CM, width, label='Convicts(Male)')
plt.bar(ind+width+width+width+width+width, listTypeGenYear30_50DM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYear30_50OM, width, label='Others(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Convicts(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(15,6))

plt.bar(ind, listTypeGenYear30_50CF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYear30_50DF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYear30_50OF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYear30_50UTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width+width, listTypeGenYear30_50DM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYear30_50OM, width, label='Others(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %% [markdown]
# ## Comparison of No. of Prisoners of age 50+ on grounds of Type and Gender over Years.

# %%
listTypeGenYear50CF = grpTypeGenYear['Age 50+'].take(np.arange(0,104,8))
listTypeGenYear50CF
# Out:
# Year  Type      Gender
# 2001  Convicts  Female     382
# 2002  Convicts  Female     442
# 2003  Convicts  Female     578
# 2004  Convicts  Female     639
# 2005  Convicts  Female     680
# 2006  Convicts  Female     705
# 2007  Convicts  Female     743
# 2008  Convicts  Female     956
# 2009  Convicts  Female     875
# 2010  Convicts  Female    1012
# 2011  Convicts  Female    1097
# 2012  Convicts  Female    1130
# 2013  Convicts  Female    1253
# Name: Age 50+, dtype: int64

# %%
listTypeGenYear50CM = grpTypeGenYear['Age 50+'].take(np.arange(1,104,8))
listTypeGenYear50CM
# Out:
# Year  Type      Gender
# 2001  Convicts  Male       9378
# 2002  Convicts  Male       9200
# 2003  Convicts  Male      12087
# 2004  Convicts  Male      13680
# 2005  Convicts  Male      15984
# 2006  Convicts  Male      15056
# 2007  Convicts  Male      17724
# 2008  Convicts  Male      18404
# 2009  Convicts  Male      18427
# 2010  Convicts  Male      19108
# 2011  Convicts  Male      19882
# 2012  Convicts  Male      20902
# 2013  Convicts  Male      21760
# Name: Age 50+, dtype: int64

# %%
listTypeGenYear50DF = grpTypeGenYear['Age 50+'].take(np.arange(2,104,8))
listTypeGenYear50DF
# Out:
# Year  Type     Gender
# 2001  Detenus  Female    20
# 2002  Detenus  Female    19
# 2003  Detenus  Female    23
# 2004  Detenus  Female    27
# 2005  Detenus  Female    10
# 2006  Detenus  Female    10
# 2007  Detenus  Female    50
# 2008  Detenus  Female     9
# 2009  Detenus  Female    17
# 2010  Detenus  Female     6
# 2011  Detenus  Female    13
# 2012  Detenus  Female     9
# 2013  Detenus  Female    14
# Name: Age 50+, dtype: int64

# %%
listTypeGenYear50DM = grpTypeGenYear['Age 50+'].take(np.arange(3,104,8))
listTypeGenYear50DM
# Out:
# Year  Type     Gender
# 2001  Detenus  Male      106
# 2002  Detenus  Male      375
# 2003  Detenus  Male      376
# 2004  Detenus  Male      288
# 2005  Detenus  Male      334
# 2006  Detenus  Male      182
# 2007  Detenus  Male      428
# 2008  Detenus  Male      295
# 2009  Detenus  Male      122
# 2010  Detenus  Male      141
# 2011  Detenus  Male      158
# 2012  Detenus  Male      180
# 2013  Detenus  Male      126
# Name: Age 50+, dtype: int64

# %%
listTypeGenYear50OF = grpTypeGenYear['Age 50+'].take(np.arange(4,104,8))
listTypeGenYear50OF
# Out:
# Year  Type    Gender
# 2001  Others  Female    161
# 2002  Others  Female    123
# 2003  Others  Female      0
# 2004  Others  Female    213
# 2005  Others  Female    272
# 2006  Others  Female    215
# 2007  Others  Female      5
# 2008  Others  Female      0
# 2009  Others  Female      0
# 2010  Others  Female      3
# 2011  Others  Female      5
# 2012  Others  Female      5
# 2013  Others  Female      8
# Name: Age 50+, dtype: int64

# %%
listTypeGenYear50OM = grpTypeGenYear['Age 50+'].take(np.arange(5,104,8))
listTypeGenYear50OM
# Out:
# Year  Type    Gender
# 2001  Others  Male       819
# 2002  Others  Male      1103
# 2003  Others  Male       188
# 2004  Others  Male       513
# 2005  Others  Male       759
# 2006  Others  Male       756
# 2007  Others  Male        85
# 2008  Others  Male        43
# 2009  Others  Male        45
# 2010  Others  Male        78
# 2011  Others  Male        84
# 2012  Others  Male        47
# 2013  Others  Male        64
# Name: Age 50+, dtype: int64

# %%
listTypeGenYear50UTF = grpTypeGenYear['Age 50+'].take(np.arange(6,104,8))
listTypeGenYear50UTF
# Out:
# Year  Type          Gender
# 2001  Under Trials  Female     944
# 2002  Under Trials  Female     857
# 2003  Under Trials  Female     911
# 2004  Under Trials  Female     870
# 2005  Under Trials  Female    1094
# 2006  Under Trials  Female    1331
# 2007  Under Trials  Female    1364
# 2008  Under Trials  Female    1474
# 2009  Under Trials  Female    1535
# 2010  Under Trials  Female    1451
# 2011  Under Trials  Female    1512
# 2012  Under Trials  Female    1861
# 2013  Under Trials  Female    1959
# Name: Age 50+, dtype: int64

# %%
listTypeGenYear50UTM = grpTypeGenYear['Age 50+'].take(np.arange(7,104,8))
listTypeGenYear50UTM
# Out:
# Year  Type          Gender
# 2001  Under Trials  Male      19537
# 2002  Under Trials  Male      21974
# 2003  Under Trials  Male      22051
# 2004  Under Trials  Male      21188
# 2005  Under Trials  Male      23588
# 2006  Under Trials  Male      27972
# 2007  Under Trials  Male      21899
# 2008  Under Trials  Male      25959
# 2009  Under Trials  Male      26408
# 2010  Under Trials  Male      24854
# 2011  Under Trials  Male      24707
# 2012  Under Trials  Male      28730
# 2013  Under Trials  Male      28615
# Name: Age 50+, dtype: int64

# %%
N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(15,6))

plt.bar(ind, listTypeGenYear50CF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYear50DF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYear50OF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYear50UTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width, listTypeGenYear50CM, width, label='Convicts(Male)')
plt.bar(ind+width+width+width+width+width, listTypeGenYear50DM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYear50OM, width, label='Others(Male)')
plt.bar(ind+width+width+width+width+width+width+width, listTypeGenYear50UTM, width, label='Under Trials(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Under Trials(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(15,6))

plt.bar(ind, listTypeGenYear50CF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYear50DF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYear50OF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYear50UTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width, listTypeGenYear50CM, width, label='Convicts(Male)')
plt.bar(ind+width+width+width+width+width, listTypeGenYear50DM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYear50OM, width, label='Others(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %%
# Only for better visualization we are removing Convicts(Male) because it is very big.

N = 13
ind = np.arange(N)
width = 0.1

plt.figure(figsize=(15,6))

plt.bar(ind, listTypeGenYear50CF, width, label='Convicts(Female)')
plt.bar(ind+width, listTypeGenYear50DF, width, label='Detenus(Female)')
plt.bar(ind+width+width, listTypeGenYear50OF, width, label='Others(Female)')
plt.bar(ind+width+width+width, listTypeGenYear50UTF, width, label='Under Trials(Female)')
plt.bar(ind+width+width+width+width+width, listTypeGenYear50DM, width, label='Detenus(Male)')
plt.bar(ind+width+width+width+width+width+width, listTypeGenYear50OM, width, label='Others(Male)')

plt.ylabel("Number", size=13)

plt.xticks(ind + width, np.arange(2001,2014))
plt.legend()

plt.show()

# %% [markdown]
# ## Thank you!
